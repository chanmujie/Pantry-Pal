# %% [markdown]
# # 1. Data preparation
# In this section, the data will first be prepared for model training.

# %% [markdown]
# Install required external Python libraries for training and evaluation of the Flan-T5 model.

# %%
# %pip install evaluate
# %pip install -U transformers
# %pip install rouge_score
# %pip install bert_score
# Out:
# Collecting evaluate
#   Downloading evaluate-0.4.6-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: datasets>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from evaluate) (4.0.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from evaluate) (2.0.2)
# Requirement already satisfied: dill in /usr/local/lib/python3.12/dist-packages (from evaluate) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from evaluate) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.12/dist-packages (from evaluate) (2.32.4)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.12/dist-packages (from evaluate) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from evaluate) (3.6.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.12/dist-packages (from evaluate) (0.70.16)
# Requirement already satisfied: fsspec>=2021.05.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from evaluate) (0.36.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from evaluate) (25.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0.0->evaluate) (3.20.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0.0->evaluate) (18.1.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0.0->evaluate) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (3.13.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.7.0->evaluate) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.7.0->evaluate) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate) (2025.10.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->evaluate) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->evaluate) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->evaluate) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.22.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.17.0)
# Downloading evaluate-0.4.6-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 2.5 MB/s eta 0:00:00
# Installing collected packages: evaluate
# Successfully installed evaluate-0.4.6
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.57.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2025.10.5)
# Collecting rouge_score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from rouge_score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.12/dist-packages (from rouge_score) (3.9.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from rouge_score) (2.0.2)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.12/dist-packages (from rouge_score) (1.17.0)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk->rouge_score) (8.3.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk->rouge_score) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk->rouge_score) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from nltk->rouge_score) (4.67.1)
# Building wheels for collected packages: rouge_score
#   Building wheel for rouge_score (setup.py) ... done
#   Created wheel for rouge_score: filename=rouge_score-0.1.2-py3-none-any.whl size=24934 sha256=472f02fa81655b32d04fb9194aeb7edcd21bc64dae5c7efa3be7ceda7ff69589
#   Stored in directory: /root/.cache/pip/wheels/85/9d/af/01feefbe7d55ef5468796f0c68225b6788e85d9d0a281e7a70
# Successfully built rouge_score
# Installing collected packages: rouge_score
# Successfully installed rouge_score-0.1.2
# Collecting bert_score
#   Downloading bert_score-0.3.13-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: torch>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from bert_score) (2.8.0+cu126)
# Requirement already satisfied: pandas>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from bert_score) (2.2.2)
# Requirement already satisfied: transformers>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from bert_score) (4.57.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from bert_score) (2.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from bert_score) (2.32.4)
# Requirement already satisfied: tqdm>=4.31.1 in /usr/local/lib/python3.12/dist-packages (from bert_score) (4.67.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from bert_score) (3.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from bert_score) (25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.1->bert_score) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.1->bert_score) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.1->bert_score) (2025.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert_score) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert_score) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert_score) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert_score) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert_score) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert_score) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert_score) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert_score) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert_score) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert_score) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert_score) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert_score) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert_score) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert_score) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert_score) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert_score) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert_score) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert_score) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert_score) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert_score) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert_score) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert_score) (3.4.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=3.0.0->bert_score) (0.36.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers>=3.0.0->bert_score) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers>=3.0.0->bert_score) (2024.11.6)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=3.0.0->bert_score) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers>=3.0.0->bert_score) (0.6.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bert_score) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bert_score) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bert_score) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bert_score) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bert_score) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bert_score) (3.2.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->bert_score) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->bert_score) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->bert_score) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->bert_score) (2025.10.5)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers>=3.0.0->bert_score) (1.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.1->bert_score) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.0.0->bert_score) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.0.0->bert_score) (3.0.3)
# Downloading bert_score-0.3.13-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 2.6 MB/s eta 0:00:00
# Installing collected packages: bert_score
# Successfully installed bert_score-0.3.13

# %% [markdown]
# ## 1.1 Load necessary libraries and dataset

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
# Set memory optimization environment variables
os.environ['PYTORCH_CUDA_ALLOC_CONF'] = 'expandable_segments:True'

OUTPUT_DIR = "/content/drive/MyDrive/recipe_model/checkpoints_test"
os.makedirs(OUTPUT_DIR, exist_ok=True)
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import torch
import evaluate
import ast
import time
from datasets import load_dataset, Dataset
from transformers import DataCollatorForSeq2Seq, T5Tokenizer, T5ForConditionalGeneration, Seq2SeqTrainingArguments, Seq2SeqTrainer
from google.colab import drive
from sklearn.model_selection import train_test_split
from peft import LoraConfig, get_peft_model, TaskType, PeftModel, PeftConfig
from tqdm import tqdm
from bert_score import score as bert_score
from sklearn.metrics.pairwise import cosine_similarity, pairwise_distances
from sklearn.preprocessing import normalize

# %%
torch.cuda.empty_cache() # clear GPU memory

df = pd.read_csv(
    "recipes_w_search_terms.csv",
    engine='python',
    encoding='utf-8'
)

# Clean unusual line terminators and strip spaces
df = df.map(
    lambda x: str(x).replace('\u2028', '\n').replace('\u2029', '\n').strip().lower()
    if isinstance(x, str) else x
)

df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 494963 entries, 0 to 494962
# Data columns (total 10 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   id                   494963 non-null  int64
#  1   name                 494963 non-null  object
#  2   description          485362 non-null  object
#  3   ingredients          494963 non-null  object
#  4   ingredients_raw_str  494963 non-null  object
#  5   serving_size         494963 non-null  object
#  6   servings             494963 non-null  int64
#  7   steps                494963 non-null  object
#  8   tags                 494963 non-null  object
#  9   search_terms         494963 non-null  object
# dtypes: int64(2), object(8)
# memory usage: 37.8+ MB
#        id                                   name  \
# 0   96313            grilled garlic cheese grits
# 1  232037  simple shrimp and andouille jambalaya
# 2   41090             black-and-white bean salad
# 3   60656             crock pot italian zucchini
# 4  232047          beef stew with dried cherries
#
#                                          description  \
# 0  we love grits, this is another good way to ser...
# 1  simple, easy and very tasty for when you are i...
# 2                                                NaN
# 3  this is a good recipe for weight watchers. it ...
# 4  this is a fabulous stew that came from one of ...
#
#                                          ingredients  \
# 0  ['water', 'grits', 'salt', 'cheddar cheese', '...
# 1  ['onion', 'red bell pepper', 'garlic cloves', ...
# 2  ['white beans', 'canned black beans', 'tomatoe...
# 3  ['zucchini', 'yellow squash', 'diced tomatoes'...
# 4  ['beef stew meat', 'flour', 'salt', 'allspice'...
#
#                                  ingredients_raw_str serving_size  servings  \
# 0  ["4   cups    water","1   cup   uncooked old f...    1 (155 g)         8
# 1  ["1   medium    onion, chopped coarse ","1   m...    1 (366 g)         4
# 2  ["1   cup   canned white beans, rinsed and dra...    1 (807 g)         1
# 3  ["2       zucchini, sliced ","2   small    yel...    1 (244 g)         4
# 4  ["3   lbs    beef stew meat","3   tablespoons ...    1 (358 g)         8
#
#                                                steps  \
# 0  ['i a sauce pan, bring water to a boil; slowly...
# 1  ['in a food processor, pulse the onion, red pe...
# 2  ['in a large bowl, combine beans, tomato, onio...
# 3  ['put all ingredients in the crock pot and coo...
# 4  ['preheat oven to 350°f.', "cut beef into 1 in...
#
#                                                 tags  \
# 0  ['time-to-make', 'course', 'main-ingredient', ...
# 1  ['60-minutes-or-less', 'time-to-make', 'course...
# 2  ['15-minutes-or-less', 'time-to-make', 'course...
# 3  ['weeknight', 'time-to-make', 'course', 'main-...
# 4  ['time-to-make', 'course', 'main-ingredient', ...
#
#                                         search_terms
# 0  {'diabetic', 'low-calorie', 'vegetarian', 'low...
# 1                               {'dinner', 'shrimp'}
# 2  {'vegetarian', 'salad', 'side', 'dinner', 'veg...
# 3                  {'side', 'vegetarian', 'italian'}
# 4                                         {'dinner'}

# %% [markdown]
# ## 1.2 Data cleaning and preprocessing
# The raw dataset has to be cleaned and reformatted into a structure suitable for modelling and text-to-text generation.
#
# Many of the fields in this dataset are stored as string representations of Python lists, hence it needs to be safely parsed into actual lists. After parsing, the data is normalised by converting all text to lowercase and removing unnecessary whitespace. This ensures that the format is consistent and does not introduce noise into the training process. Rows that lack important information like the `ingredients` and `steps` are removed.
#
# Each recipe is transformed into an input-output pair that aligns with the model's objective. The model's input is formed by joining the cleaned ingredient names into a single comma-separated string, while the target output will be a structured text block consisting of the recipe title, the expanded ingredient list, and the instructions. These are stored in the `input_text` and `target_text` columns.

# %%
# Safely parse list-like strings
def safe_parse(x):
    try:
        return ast.literal_eval(x)
    except Exception:
        return []

# Normalise whitespace and lowercase
def clean_whitespace(x):
    if isinstance(x, str):
        return re.sub(r'\s+', ' ', x).strip().lower()
    elif isinstance(x, list):
        return [re.sub(r'\s+', ' ', i).strip().lower() for i in x if isinstance(i, str)]
    return x

# Apply cleaning functions
df["ingredients"] = df["ingredients"].apply(safe_parse).apply(clean_whitespace)
df["ingredients_raw_str"] = df["ingredients_raw_str"].apply(safe_parse).apply(clean_whitespace)
df["steps"] = df["steps"].apply(safe_parse).apply(clean_whitespace)

# Drop incomplete rows
df = df[df["ingredients"].map(len) > 0]
df = df[df["steps"].map(len) > 0]

# Format examples for training
def format_training_example(row):
    title = str(row.get("name", "")).strip().lower()
    ingredients_in = ", ".join(row["ingredients"])
    ingredients_out = "\n".join(row["ingredients_raw_str"])
    steps = "\n".join(row["steps"])
    recipe_text = f"{title}\n\ningredients:\n{ingredients_out}\n\nsteps:\n{steps}"
    return ingredients_in, recipe_text

# Apply formatting
df["input_text"], df["target_text"] = zip(*df.apply(format_training_example, axis=1))

# Drop rows missing either field and reset index
df = df.dropna(subset=["input_text", "target_text"]).reset_index(drop=True)

# Get the validation set
sampling_df = df[80001:]
df = df[:80000]

# Show example
print(df.head(1)[["input_text", "target_text"]].to_string())
# Out:
#                                               input_text                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       target_text
# 0  water, grits, salt, cheddar cheese, garlic, olive oil  grilled garlic cheese grits\n\ningredients:\n4 cups water\n1 cup uncooked old fashion grits\n1 teaspoon salt\n4 ounces shredded cheddar cheese\n1 -2 clove garlic, minced\n1 tablespoon olive oil\n\nsteps:\ni a sauce pan, bring water to a boil; slowly add grits and salt, stirring constantly; reduce heat:simmer, uncovered, for 40-45 minutes or untill thickened, stirrin occasionally.\nadd cheese and garlic; stir until cheese is melted, spray 9-inch baking dish with nonstick cooking spray; cover and refrigerate for 2 to 2 1/2 hours or until frim.\nbefore starting the grill, coat the grill rack with nonstick cooking spray; cut the grits into 3-inch squares; brush both sides with olive oil.\ngrill, covered, over medium heat for 4 to 6 minutes on each side or until lightly browned.

# %% [markdown]
# ## 1.3 Split data
# After cleaning and formatting the dataset, it is first split into train and test sets using a 90/10 split, with a fixed random seed to ensure reproducibility.
#
# As we are training a Hugging Face transformer model, we need a validation set as well. However, we did not include that in our LSTM model training. As such, we created a separate validation set by sampling from the previously reserved `sampling_df`, providing an independent subset for tuning hyperparameters and monitoring model performance during training. \
# This results in a train, validation, and test datasets with a split of 80/10/10.
#
# Each of these subsets is then converted into Hugging Face `Dataset` objects, allowing efficient integration with the `Seq2SeqTrainer` and other utilities.

# %%
# Create hugging face dataset
train_df, test_df = train_test_split(df, test_size=0.1, random_state=42)
val_df = sampling_df.sample(n=8000, random_state=42)
train_dataset = Dataset.from_pandas(train_df)
val_dataset = Dataset.from_pandas(val_df)
test_dataset = Dataset.from_pandas(test_df)

# %% [markdown]
# # 2. Model building and training (FLAN)

# %% [markdown]
# ## 2.1 Tokenisation and input preparation
# Different from the steps taken when training the LSTM model, the Flan-T5 transformer model is tokenised after splitting and before model training. This is due to the two models using different training paradigms.
# - LSTM requires the data to be tokenised before splitting as the data structure (X, Y) depends on it.
# - Flan-T5 tokenisation does no depend on X/Y shifting, so it happens after splitting of dataset to prevent data leakage.
# - X = tokens[0:n-1], Y = tokens[1:n]
#
# After splitting the dataset into training, validation, and test datasets, the raw text fields are converted into token IDs that the Flan-T5 model can process.
#
# The pretrained Flan-T5 tokeniser and model are loaded, and the maximum sequence lengths for both the input and the target output are defined. The ingredient list is prefixed with an instruction prompt so that the model understands the task and is consistent with its generation behaviour. Both inputs and target recipe texts are tokenised using fixed maximum lengths, with truncation and padding applied to maintain uniform tensor shapes.
#
# Padding tokens are replaced with `-100` so that they are ignored during loss computation (standard practice for seq2seq models). The preprocessing function is applied to all datasets, producing tokenised datasets that are ready for training.
#
# `DataCollatorForSeq2Seq` dynamically batches and pad examples during training in a way that is compatible with Flan-T5's encoder-decoder architecture.

# %%
# model_name = "google/flan-t5-base"
model_name = "google/flan-t5-small"

tokenizer = T5Tokenizer.from_pretrained(model_name)
model = T5ForConditionalGeneration.from_pretrained(model_name)

max_input = 128
max_target = 256

def preprocess_function(examples):
    inputs = ["Generate a recipe with measurements using: " + ing for ing in examples["input_text"]]
    model_inputs = tokenizer(
        inputs,
        max_length=max_input,
        truncation=True,
        padding="max_length",
    )

    # Tokenize targets (labels)
    with tokenizer.as_target_tokenizer():
        labels = tokenizer(
            examples["target_text"],
            max_length=max_target,
            truncation=True,
            padding="max_length",
        )

    labels["input_ids"] = [
        [(l if l != tokenizer.pad_token_id else -100) for l in label]
        for label in labels["input_ids"]
    ]

    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

tokenized_train = train_dataset.map(preprocess_function, batched=True)
tokenized_val = val_dataset.map(preprocess_function, batched=True)
tokenized_test = test_dataset.map(preprocess_function, batched=True)

data_collator = DataCollatorForSeq2Seq(tokenizer=tokenizer, model=model)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/308M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# Map:   0%|          | 0/72000 [00:00<?, ? examples/s]
# /usr/local/lib/python3.12/dist-packages/transformers/tokenization_utils_base.py:4034: UserWarning: `as_target_tokenizer` is deprecated and will be removed in v5 of Transformers. You can tokenize your labels by using the argument `text_target` of the regular `__call__` method (either in the same call as your input texts if you use the same keyword arguments, or in a separate call.
#   warnings.warn(
# Map:   0%|          | 0/8000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/8000 [00:00<?, ? examples/s]

# %% [markdown]
# ## 2.2 LoRA configuration (parameter-efficient fine-tuning (PEFT))
# Low-Rank Adaptation (LoRA) is applied to fine-tune and train Flan-T5 efficiently. This allows the model to adapt to the recipe-generation task while keeping most of the pretrained weights frozen, resulting in significantly lower memory usage and faster training.
#
# LoRA hyperparameters are defined to balance training stability and model quality. Target modules corresponding to the key projection layers within the T5 attention blocks where LoRA adaptors should be injected are also specified.
#
# The base model is then wrapped with the LoRA adaptors using `get_peft_model`.

# %%
# LoRA configuration
lora_config = LoraConfig(
    task_type=TaskType.SEQ_2_SEQ_LM,
    inference_mode=False,
    r=16,
    lora_alpha=32,
    lora_dropout=0.1,
    target_modules=["q", "v", "k", "o"], # for more comprehensive targeting
    bias="none",
)

# Wrap base model with LoRA adaptors
model = get_peft_model(model, lora_config)

# Verify that PEFT is correctly applied
model.print_trainable_parameters()
# Out:
# trainable params: 1,376,256 || all params: 78,337,408 || trainable%: 1.7568

# %% [markdown]
# ## 2.3 Training configuration and hyperparameters
# The training hyperparameters are defined in this section.

# %%
batch_size = 4

args = Seq2SeqTrainingArguments(
    output_dir=OUTPUT_DIR,
    eval_strategy="epoch",
    eval_steps=2000,
    save_strategy="epoch",
    save_steps=2000,
    learning_rate=5e-5,
    per_device_train_batch_size=4,
    gradient_accumulation_steps=2,
    num_train_epochs=3,
    warmup_steps=500,
    weight_decay=0.01,
    save_total_limit=2,
    logging_steps=100,
    fp16=False,
    bf16=torch.cuda.is_bf16_supported(),
    report_to="none",
    max_grad_norm=1.0,
    logging_dir="./logs",
    load_best_model_at_end=True,
    predict_with_generate=True,
    dataloader_num_workers=1,
    optim="adamw_torch_fused",
    dataloader_pin_memory=False,
)

# %%
# Check memory status
print(f"GPU memory allocated: {torch.cuda.memory_allocated() / 1024**3:.2f} GB")
print(f"GPU memory reserved: {torch.cuda.memory_reserved() / 1024**3:.2f} GB")
print(f"GPU memory free: {torch.cuda.get_device_properties(0).total_memory - torch.cuda.memory_allocated() / 1024**3:.2f} GB")
# Out:
# GPU memory allocated: 0.00 GB
# GPU memory reserved: 0.00 GB
# GPU memory free: 15828320256.00 GB

# %% [markdown]
# ## 2.4 Initialise the Trainer
# This section initialises a Hugging Face `Seq2SeqTrainer`, which provides a high-level training loop tailored for encoder-decoder models like Flan-T5.
#
# It handles batching, forward and backward passes, gradient updates, evaluation, and checkpointing, simplifying the fine-tuning workflow.

# %%
trainer = Seq2SeqTrainer(
    model=model,
    args=args,
    train_dataset=tokenized_train,
    eval_dataset=tokenized_val,
    tokenizer=tokenizer,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
)
# Out:
# /tmp/ipython-input-867266061.py:4: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Seq2SeqTrainer.__init__`. Use `processing_class` instead.
#   trainer = Seq2SeqTrainer(

# %% [markdown]
# ## 2.5 Train model
# The model is trained in this section. During training, the model iteratively updates its LoRA adaptor weigfhts based on the training data while periodically evaluating its performance on the validation set.
#
# The trained model is saved to Google Drive such that it can be reloaded later for evaluation without retraining. The tokeniser is also saved to ensure that preprocessing and text generation remain consistent across current and future sessions.
#
# Model was trained in separate sessions as T4 GPU time ran out.

# %%
# Train model
trainer.train()

# Save model to drive
save_path = "/content/drive/MyDrive/recipe_model/final_model"
trainer.save_model(save_path)
tokenizer.save_pretrained(save_path)

print(f"Path model is saved to: {save_path}")

# %%
# Continue training from previous saved checkpoint
checkpoints = [d for d in os.listdir(OUTPUT_DIR) if d.startswith("checkpoint")]
print(OUTPUT_DIR)
latest_checkpoint = max(
    checkpoints,
    key=lambda x: int(re.search(r"checkpoint-(\d+)", x).group(1))
)

latest_checkpoint = os.path.join(OUTPUT_DIR, latest_checkpoint)
print(f"Resuming from: {latest_checkpoint}")
# Out:
# /content/drive/MyDrive/recipe_model/checkpoints_test
# Resuming from: /content/drive/MyDrive/recipe_model/checkpoints_test/checkpoint-18000

# %%
# Resume training
trainer.train(resume_from_checkpoint=latest_checkpoint)

# Save model to drive
save_path = "/content/drive/MyDrive/recipe_model/final_model"
trainer.save_model(save_path)
tokenizer.save_pretrained(save_path)

print(f"Path model is saved to: {save_path}")

# %% [markdown]
# # 3. Model evaluation (FLAN-T5)

# %% [markdown]
# ## 3.1 Reloading model for evaluation

# %%
model_dir = "/content/drive/MyDrive/recipe_model/final_model"

# Load the base model
base_model = T5ForConditionalGeneration.from_pretrained(
    "google/flan-t5-small",
    torch_dtype=torch.float16 if torch.cuda.is_available() else torch.float32
)

# Load the LoRA adapter
model = PeftModel.from_pretrained(base_model, model_dir)

# Merge LoRA weights for faster inference
model = model.merge_and_unload()

# Move to GPU and set to eval mode
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)
model.eval()

# Load tokenizer
tokenizer = T5Tokenizer.from_pretrained(model_dir)

# %% [markdown]
# ## 3.2 Generating sample recipes for qualitative analysis

# %%
# Helper function to generate recipe from list of ingredients
def generate_recipe(ingredients, model, tokenizer, max_length=256):
    # Join ingredients
    if isinstance(ingredients, list):
        ingredients_text = ", ".join(ingredients)
    else:
        ingredients_text = ingredients

    input_text = f"Generate a recipe with measurements using: {ingredients_text}"

    # Tokenise
    inputs = tokenizer(
        input_text,
        return_tensors="pt",
        max_length=128,
        truncation=True
    )

    # Move inputs to same device as model
    device = next(model.parameters()).device
    inputs = {k: v.to(device) for k, v in inputs.items()}

    # Generate
    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_length=max_length,
            num_beams=4,
            early_stopping=True,
            no_repeat_ngram_size=3,
            temperature=0.7,
        )

    return tokenizer.decode(outputs[0], skip_special_tokens=True)

# Test
ingredients = ["chicken breast", "garlic", "olive oil", "lemon", "pepper"]
recipe = generate_recipe(ingredients, model, tokenizer)
print(recipe)
# Out:
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# chicken fried chicken ingredients: 1 lb chicken breast 1 garlic, chopped 1 tablespoon olive oil 1 lemon, minced pepper steps: preheat oven to 350°f. in a large skillet, saute garlic, olive oil, lemon, and pepper. add chicken and cook until chicken is tender, about 5 minutes. add lemon and pepper and cook for about 10 minutes.

# %%
# Testing various ingredients
# Example 1
ingredients = ["onion", "salt", "flour"]
recipe1 = generate_recipe(ingredients, model, tokenizer)
print(recipe1)

# Example 2
ingredients = ["chocolate", "salt"]
recipe2 = generate_recipe(ingredients, model, tokenizer)
print(recipe2)

# Example 3
ingredients = ["potato", "flour", "onion", "garlic", "oil"]
recipe3 = generate_recipe(ingredients, model, tokenizer)
print(recipe3)

# Example 4
ingredients = ["egg", "leek"]
recipe4 = generate_recipe(ingredients, model, tokenizer)
print(recipe4)
# Out:
# onion &amp; flour ingredients: 1 lb onion, minced 1 teaspoon salt 1 cup flour steps: preheat oven to 350°f. in a large bowl, combine onion, salt, flour, and flour. mix well. stir in flour. stir until well combined. add flour and stir until smooth.
# chocolate cake ingredients: 1 cup chocolate 1 teaspoon salt steps: preheat oven to 350°f. melt chocolate and salt in a large saucepan over medium heat. add the chocolate and stir until the chocolate melts. stir in the salt and stir to combine. serve.
# fried potato ingredients: 1 lb potato 1 cup flour 1 onion 1 garlic 1 tablespoon oil steps: preheat oven to 350°f. in a large bowl, combine flour, onion, garlic, oil, and oil. add potatoes and cook until potatoes are tender, about 5 minutes. remove potatoes from heat. add flour and cook for 1 minute. add onion and garlic. cook for another 5 minutes, or until onions are tender. add oil and cook, stirring occasionally.
# leek &amp; leeks ingredients: 1 egg 1 lb leekk steps: preheat oven to 350°f. in a large bowl, combine egg, leeks, and leeks. add the egg and mix well. stir in the leeks and continue to mix until the egg is incorporated. place on a baking sheet and bake for 30 minutes or until a toothpick comes out clean.

# %% [markdown]
# ## 3.3 Stratified sampling & batch generation
# Instead of running inference on the full test set, a smaller representative sample is selected to reduce computation time. Recipe generation is then performed in batches, which allows the model to process multiple inputs simultaneously.

# %%
SAMPLE_SIZE = 500  # reduce from 8000 to 500
np.random.seed(42)
sample_indices = np.random.choice(len(test_dataset), size=min(SAMPLE_SIZE, len(test_dataset)), replace=False)

# Batch generation for speed
def generate_batch(input_texts, model, tokenizer, batch_size=8, max_length=256):
    all_predictions = []
    num_batches = (len(input_texts) + batch_size - 1) // batch_size

    with tqdm(total=len(input_texts), desc="Generating recipes", unit="recipe") as pbar:
        for i in range(0, len(input_texts), batch_size):
            batch = input_texts[i:i+batch_size]
            inputs = ["Generate a recipe with measurements using: " + ing for ing in batch]

            # Tokenise batch
            model_inputs = tokenizer(
                inputs,
                return_tensors="pt",
                max_length=128,
                truncation=True,
                padding=True
            )
            model_inputs = {k: v.to(model.device) for k, v in model_inputs.items()}

            # Generate for batch
            with torch.no_grad():
                outputs = model.generate(
                    **model_inputs,
                    max_length=max_length,
                    num_beams=4,
                    early_stopping=True,
                    no_repeat_ngram_size=3,
                    temperature=0.7,
                )

            # Decode batch
            batch_predictions = tokenizer.batch_decode(outputs, skip_special_tokens=True)
            all_predictions.extend(batch_predictions)

            # Update progress bar
            pbar.update(len(batch))

            # Show speed estimate every 50 recipes
            if len(all_predictions) % 50 == 0:
                pbar.set_postfix({"completed": f"{len(all_predictions)}/{len(input_texts)}"})

    return all_predictions

# Generate predictions for sampled test set
print("Generating predictions with batching...")
input_texts = [test_dataset[int(i)]["input_text"] for i in sample_indices]
references = [test_dataset[int(i)]["target_text"] for i in sample_indices]

# Batch generation
predictions = generate_batch(input_texts, model, tokenizer, batch_size=8)
print(f"Generated {len(predictions)} predictions")
# Out:
# 📊 Evaluating on 500 samples instead of 8000
# Generating predictions with batching...
# 🍳 Generating recipes: 100%|██████████| 500/500 [06:28<00:00,  1.29recipe/s, completed=500/500]
# ✅ Generated 500 predictions

# %% [markdown]
# ## 3.4 Run evaluation

# %%
# BERTScore (semantic similarity)
P, R, F1 = bert_score(predictions, references, lang="en", verbose=True)
print(f"  Precision: {P.mean():.4f}")
print(f"  Recall: {R.mean():.4f}")
print(f"  F1: {F1.mean():.4f}")
# Out:
# 🟢 Computing BERTScore (this may take a while)...
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/482 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.42G [00:00<?, ?B/s]
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# calculating scores...
# computing bert embedding.
#   0%|          | 0/16 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/8 [00:00<?, ?it/s]
# done in 31.69 seconds, 15.78 sentences/sec
#   Precision: 0.8823
#   Recall: 0.8361
#   F1: 0.8584

# %%
# Helper function to extract ingredients from recipe text
def extract_ingredients(text):
    if "ingredients:" in text.lower():
        parts = text.lower().split("ingredients:")
        if len(parts) > 1:
            ing_section = parts[1].split("steps:")[0] if "steps:" in parts[1] else parts[1]
            return [line.strip() for line in ing_section.strip().split('\n') if line.strip()]
    return []

# Defining function to calculate ingredient coverage: % of true ingredients that appear in predictions
def ingredient_coverage(pred_ingredients, true_ingredients):
    if not true_ingredients:
        return 0.0
    pred_text = " ".join(pred_ingredients).lower()
    matches = sum(1 for ing in true_ingredients if any(word in pred_text for word in ing.lower().split()))
    return matches / len(true_ingredients)

# Compile average ingredient coverage across generated recipes
ingredient_coverages = []

for pred, ref in zip(predictions, references):
    pred_ings = extract_ingredients(pred)
    ref_ings = extract_ingredients(ref)

    coverage = ingredient_coverage(pred_ings, ref_ings)
    ingredient_coverages.append(coverage)

print(f"\n  Avg Ingredient Coverage: {np.mean(ingredient_coverages):.2%}")
# Out:
#   Avg Ingredient Coverage: 98.45%

# %%
# Generating sample vs true recipes for human evaluation
for i in range(min(30, len(predictions))):
    print(f"\n🔹 Example {i+1}")
    print(f"Input: {input_texts[i]}")
    print(f"\nGenerated Recipe:\n{predictions[i]}")
    print(f"\nTrue Recipe:\n{references[i]}")
    print("-"*80)
# Out:
# 🔹 Example 1
# Input: walnuts, fresh basil leaves, garlic, lemon%2c zest of, butter, seasoning salt, lemon %26 herb seasoning, fresh ground black pepper, boneless skinless chicken breasts, egg, panko breadcrumbs, salt %26 freshly ground black pepper, extra virgin olive oil
#
# Generated Recipe:
# grilled chicken breasts ingredients: 1 lb walnuts 2 tablespoons fresh basil leaves 1 tablespoon garlic, minced 1 lemon, zest of 1 tablespoon butter 1 teaspoon seasoning salt 1 teaspoon lemon % herb seasoning 1 teaspoon fresh ground black pepper 1 boneless skinless chicken breast, sliced 1 egg 1 cup panko breadcrumbs salt & freshly ground pepper 1 tablespoon extra virgin olive oil steps: preheat oven to 350°f. in a large bowl, combine the walnuts, basil leaves, garlic, lemon zest of, butter, seasoning, salt and pepper. stir in the lemon &amp; herb. add the butter and season with salt. whisk in the seasonings. beat in the pepper and cook until the chicken is tender, about 5 minutes. remove from heat and add the chicken to the skillet and cook for 5 minutes, or until chicken is browned and tender.
#
# True Recipe:
# chicken breasts stuffed with basil walnut butter
#
# ingredients:
# 3/4 cup toasted walnuts, chopped medium-fine (to toast walnuts, place in 325 degree f oven for about 10-12 minutes, stirring to prevent scorching,)
# 2 cups fresh basil leaves, lightly packed,chopped
# 1 -2 clove garlic, finely chopped
# 1 lemon, zest of, grated
# 6 tablespoons butter, softened,divided
# 1/2 teaspoon seasoning salt
# 1/2 teaspoon lemon & herb seasoning or 1 teaspoon fresh lemon juice
# 1/4 teaspoon fresh ground black pepper
# 4 large boneless skinless chicken breasts, fat discarded,washed,and patted dry (about 1-1/2 lb)
# 1 egg, well beaten
# 1 1/2 cups panko breadcrumbs (coarse japanese breadcrumbs) or 1 1/2 cups regular dry breadcrumbs, if necessary,but try to find the panko if possible (can be found in most oriental markets and some supermarkets)
# additional salt & freshly ground black pepper
# 1 -2 tablespoon extra virgin olive oil (for frying)
#
# steps:
# finely chop walnuts and basil.
# place walnuts, basil, garlic, lemon zest, 5 tbsp butter, seasoned salt, and pepper in bowl of an electric mixer.
# using paddle attachment, mix on medium-high until butter is fairly smooth.
# season to taste with additional salt and pepper.
# form into an 8" long roll in plastic wrap, and place in freezer for about 20 minutes, then refrigerate until ready to use.
# place chicken breasts between sheets of plastic wrap, and pound to about 1/4" thick or less.
# try not to tear the chicken too much, but dont worry about it too much either.
# place chicken breasts skin-side down, and place 1/4 of butter mixture on wide end of each breast, shaping butter into an elongated egg shape.
# roll chicken breasts around butter, folding in ends as you go.
# if there are some splits in the meat, just overlap as you roll, and press to seal.
# refrigerate rolls for at least 30 minutes, or place in freezer for 15-20 minutes.
# while chicken is chilling, season egg wash and panko with salt and pepper as desired, and set aside.
# dip each chicken roll in the egg wash, drain off excess, and roll in panko, pressing on crumbs to make them adhere.
# rolls should be well coated all over.
# refrigerate rolls until ready to cook.
# all this freezing and/or refrigerating is just to keep the butter as cold as possible so most of it stays inside the chicken and bastes it internally.
# preheat oven to 400 degree f, and spray a medium casserole or baking dish with nonstick vegetable spray.
# heat olive oil and remaining 1 tbsp butter in a large skillet over medium-high heat.
# when very hot, add chicken rolls, and brown on all sides.
# pay close attention; the panko goes from nicely browned to blackened very rapidly.
# transfer rolls to baking dish as they brown.
# drizzle drippings and crumbs from skillet over the rolls if desired, and bake to finish cooking for about 10-15 minutes.
# transfer chicken to a warm platter or individual serving plates, and spoon drippings over top.
# serve immediately.
# serve with brown rice pilaf and a small tossed green salad topped with croutons and crumbled feta cheese, with a spicy vinaigrette dressing.
# --------------------------------------------------------------------------------
#
# 🔹 Example 2
# Input: cooking apples, granulated sugar, all-purpose flour, granulated sugar, baking powder, salt, butter, egg, vanilla, whipped cream
#
# Generated Recipe:
# whipped cream ingredients: 1 lb cooking apples 1 cup granulated sugar 1 1/2 cups all-purpose flour 1 1/2 teaspoons granularized sugar 1 teaspoon baking powder 1 teaspoon salt 1 cup butter 1 egg 1 teaspoon vanilla 1 cup whip cream steps: preheat oven to 350°f. in a large mixing bowl, combine apples, sugar, flour, baking powder, salt, butter, egg, vanilla, and cream. mix well. stir in cream. add egg and vanilla. beat well. add cream and beat until well combined. beat until smooth.
#
# True Recipe:
# german apple torte (krummeltorte)
#
# ingredients:
#
# 2 lbs cooking apples
# 3/4 cup granulated sugar
#
# 1 cup all-purpose flour
# 2 tablespoons granulated sugar
# 1/2 teaspoon baking powder
# 1/4 teaspoon salt
# 1/2 cup butter
# 1 egg
# 1 teaspoon vanilla
#
# whipped cream
#
# steps:
# to make the filling: peel, core and quarter apples; cut each quarter crosswise into 5 or 6 pieces.
# place in empty saucepan; stir in 1/2 cup of the sugar.
# cover and simmer for 7 minutes or until apples are partially cooked.
# place in sieve to drain.
# to make the pastry: in bowl, combine flour, sugar, baking powder and salt.
# cut in butter until mixture resembles fine crumbs.
# lightly beat together egg and vanilla.
# stir into flour mixture and mix well until ball of soft dough forms.
# (if dough seems too stiff, add a few drops of water.) rolls out half the pastry to about 1/8 inch thickness and cut to fit bottom of lightly greased 8-inch springform pan.
# place drained apples on top of pastry, leaving 1/2 inch space between apples and inside edge of pan.
# crumble remaining pastry dough into currant-sized crumbs.
# drop half the crumbs into the space between apples and edge of pan.
# flatten top surface of apples and sprinkle with remaining pastry crumbs.
# sprinkle torte with remaining sugar.
# bake in 425 f.
# oven for 25 to 30 minutes or until well browned.
# remove hinged ring and serve torte on pan base.
# serve warm, garnished with whipped cream.
# makes 8 servings.
# canadian living.
# --------------------------------------------------------------------------------
#
# 🔹 Example 3
# Input: russet potatoes, oil, salt and pepper, parmesan cheese, bacon, cheddar cheese, fresh parsley, cayenne pepper, green onions, sour cream
#
# Generated Recipe:
# sour cream potatoes ingredients: 1 lb russet potatoes oil salt and pepper 2 tablespoons parmesan cheese 1 cup bacon 1 cup cheddar cheese 1 tablespoon fresh parsley 1 teaspoon cayenne pepper 1 cup green onions, sliced 1 cup sOUR cream steps: preheat oven to 350°f. in a large bowl, combine potatoes, oil, salt, and pepper. add potatoes, bacon, cheddar cheese, parsley, and paprika. add onions and cook until potatoes are tender, about 5 minutes. remove potatoes from heat and cook for about 10 minutes, or until potatoes have browned and tender. add bacon, cheese and parsley. cook for another 10 minutes or until cheese is melted, about 1 minute. add green onions and saute for a few minutes. add a little more cheese and cook, stirring occasionally, until cheese reaches a soft peaks. remove from heat, and serve warm.
#
# True Recipe:
# delicious cheesy bacon and green onion potato skins
#
# ingredients:
# 6 large russet potatoes
# oil
# salt and pepper
# 1/3 cup grated parmesan cheese
# 10 -15 slices bacon (cooked until crisp and chopped)
# 3 -4 cups cheddar cheese, finely grated
# 2 tablespoons chopped fresh parsley
# 1/4-1/2 teaspoon cayenne pepper
# 6 -7 green onions, finely chopped
# sour cream or barbecue sauce
#
# steps:
# set oven to 400°f.
# wash the outside of the potatoes, then dry very well.
# place on a baking sheet.
# bake for about 1 hour, or until the potatoes are tender (cooking time will vary depending on the size of potatoes).
# cool until able to handle.
# keep the oven heat to 400°f.
# slice the potatoes in half lengthwise.
# scoop out the pulp leaving about 1/2-inch thick layer of the cooked potato on the skins.
# oil a large baking sheet.
# place the skins on the baking sheet (skin side down, pulp side facing upwards).
# sprinkle the inside with salt and pepper and grated parmesan cheese (if using).
# in a bowl combine the shredded cheese, chopped bacon, parsley and cayenne pepper; mix to combine.
# evenly divide the cheese mixture over top of the skins.
# at this point you can cover tightly with plastic wrap refrigerate until ready to serve.
# bake for about 25 minutes, or until the skins are crisp and the cheese melts.
# transfer the skins to a platter and sprinkle with finely chopped green onions.
# serve with sour cream and/or barbecue sauce.
# --------------------------------------------------------------------------------
#
# 🔹 Example 4
# Input: olive oil, balsamic vinegar, cider vinegar, honey, garlic cloves, fresh rosemary, dijon mustard, pork tenderloin
#
# Generated Recipe:
# grilled pork tenderloin ingredients: 1 tablespoon olive oil 1 tablespoon balsamic vinegar 1 tablespoon cider vinegar 1 teaspoon honey 2 garlic cloves, minced 1 teaspoon fresh rosemary 1 teaspoon dijon mustard 1 lb pork tenderbelloin steps: preheat oven to 350°f. in a large bowl, combine olive oil, vinegar, cider vinegar, honey, garlic, rosemary, and mustard. add pork and cook until tender, about 5 minutes. remove from heat and add the pork. stir in the mustard and cook for 5 minutes or until tender.
#
# True Recipe:
# garlic and rosemary roasted pork
#
# ingredients:
# 1/2 cup olive oil
# 1/4 cup balsamic vinegar
# 2 tablespoons cider vinegar
# 2 tablespoons honey
# 3 large garlic cloves, chopped
# 1 tablespoon fresh rosemary or 2 teaspoons dried rosemary, chopped
# 1 tablespoon dijon mustard
# 16 ounces pork tenderloin
#
# steps:
# blend first 7 ingredients in processor until rosemary and garlic are finely chopped. place pork in heavy plastic bag. pour half of marinade over pork (refrigerate remaining marinade for another use). seal bag and refrigerate pork overnight, turning occasionally.
# preheat oven to 375°f drain pork; discard marinade. place pork in small roasting pan. roast until meat thermometer inserted into center registers 150°f, about 25 minutes. slice pork thinly.
# --------------------------------------------------------------------------------
#
# 🔹 Example 5
# Input: cabbage, ground beef, onion, tomato soup, water
#
# Generated Recipe:
# cabbage soup ingredients: 1 cup cabbage 1 cup ground beef 1 onion, chopped 1 cup tomato soup 1 cup water steps: preheat oven to 350°f. in a large bowl, combine cabbage, ground beef, onion, tomato soup, water, and water. add cabbage to a bowl. add water and stir until well combined. add soup and water to the bowl. stir in water. serve.
#
# True Recipe:
# easy cabbage beef bake
#
# ingredients:
# 1 head cabbage
# 1 lb ground beef
# 1 medium onion, chopped
# 1 (10 3/4 ounce) can tomato soup
# 1/2 soup can water
#
# steps:
# chop cabbage.
# brown ground beef and onion in skillet on medium heat. drain. season with salt and pepper to your liking.
# cover bottom of greased medium size casserole dish with half the cabbage.
# add beef and onion.
# put remaining cabbage on top of beef layer.
# mix tomato soup and water. pour over beef/cabbage mixture.
# cover and bake @ 375 for about one hour.
# --------------------------------------------------------------------------------
#
# 🔹 Example 6
# Input: chili, cheddar cheese, eggs, water, salt and pepper, butter, flour tortillas, onion, diced tomato, sour cream, salsa
#
# Generated Recipe:
# sour cream tortillas ingredients: 1 cup chili 1 cup cheddar cheese 2 eggs 1/2 cup water salt and pepper 2 tablespoons butter 1 cup flour tortillas 1 onion 1 cup diced tomato, diced 1 cup sOUR cream 1 cup salsa steps: preheat oven to 350°f. in a large bowl, combine chili, cheddar cheese, eggs, water, salt, and pepper. add butter and cook until smooth. add flour tortilla, onion, tomato, a pinch of salt and freshly ground black pepper. stir in salsa. add salsa and stir to combine.
#
# True Recipe:
# chili cheese omelette burritos
#
# ingredients:
# 1 cup chili, heated thru
# 1/2 cup shredded cheddar cheese
# 3 eggs, beaten with
# 1 tablespoon water
# salt and pepper, to taste
# 1 teaspoon butter or 1 teaspoon margarine
# 2 flour tortillas
# chopped onion
# diced tomato
# sour cream
# salsa
#
# steps:
# make sure all your ingredients are ready - chili hot, cheese grated, optional ingredients chopped, eggs beaten.
# heat nonstick skillet over medium high heat. add butter to pan.
# when butter is melted, add beaten eggs and scramble.
# when eggs are done, remove pan from heat and quickly heat tortillas over open flame, a few seconds on each side.
# to assemble, place half of scrambled eggs on each tortilla. sprinkle with cheese. top with chili. and add any optional ingredients.
# tuck in both sides of tortilla, and roll up, burrito style.
# serve immediately.
# --------------------------------------------------------------------------------
#
# 🔹 Example 7
# Input: sour cream, mayonnaise, fresh parsley, sweet pickle relish, spicy brown mustard, white pepper, elbow macaroni, green onion, frozen peas, sharp cheddar cheese, baby carrots, green pepper, celery
#
# Generated Recipe:
# sour cream macaroni &amp; macaronis ingredients: 1 1/2 cups lukewarm mayonnaise 1/2 cup fresh parsley 1/2 cup sweet pickle relish 1/2 teaspoon spicy brown mustard 1/2 teaspoon white pepper 1 (14 ounce) can elbow macaronei 1 large green onion 1 cup frozen peas 1 cup sharp cheddar cheese 1 lb baby carrots 1 teaspoon green pepper 1 teaspoon celery steps: preheat oven to 350°f. in a large bowl, combine cream, mayo, parsley, sweet pickles relish, brown mustard, white pepper, elbow macaronin, green onion, pea, and cheddar cheese. mix well. add carrots, green pepper, celery and celery. stir in the celery mixture. add the remaining ingredients to the mixture and stir well. pour into a greased baking dish. bake at 400°f for 30 minutes or until golden brown.
#
# True Recipe:
# macaroni salad
#
# ingredients:
# 2/3 cup sour cream (i use low fat)
# 1/3 cup mayonnaise (i use light here too)
# 2 tablespoons fresh parsley, chopped
# 2 tablespoons sweet pickle relish
# 1 tablespoon spicy brown mustard
# 1/4 teaspoon white pepper (although black works fine here)
# 4 cups cooked elbow macaroni (about 8 oz uncooked)
# 1 cup sliced green onion
# 1 cup frozen peas, thawed
# 1 cup shredded sharp cheddar cheese (i use reduced fat)
# 1/2 cup diced baby carrots
# 1/2 cup green pepper
# 1/2 cup sliced celery
#
# steps:
# combine first 6 ingredients in a large bowl; stir well.
# add macaroni and remaining ingredients.
# toss well to coat.
# cover and chill for at least 2 to 4 hours before serving.
# --------------------------------------------------------------------------------
#
# 🔹 Example 8
# Input: vegetable oil, boneless pork chops, chunky salsa, diced green chilies, ground cumin, cheddar cheese
#
# Generated Recipe:
# pork chops ingredients: 2 tablespoons vegetable oil 1 lb boneless pork chop, peeled and sliced 1 cup chunky salsa 1 cup diced green chilies 1 teaspoon ground cumin 1 cup cheddar cheese steps: preheat oven to 350°f. in a large skillet, heat oil over medium-high heat until oil reaches a boil. add onion, saute until onions are translucent, about 5 minutes. remove from heat and cook for 5 minutes, stirring occasionally. remove pork from heat. stir in chopped cilantro, cilantro, cumin, and cheddar cheese. add to pork mixture and stir to combine. add a pinch of salt and pepper to taste. serve with a side of shredded cheese.
#
# True Recipe:
# tex-mex pork chops
#
# ingredients:
# 1 teaspoon vegetable oil
# 4 boneless pork chops
# 1 1/2 cups chunky salsa
# 1 (4 ounce) can diced green chilies
# 1/2 teaspoon ground cumin
# 1/4 cup cheddar cheese, grated
#
# steps:
# heat oil in frying pan over medium high heat.
# brown chops on one side, about 2 minutes, and then flip them.
# add the salsa, chilies and cumin to skillet and mix well.
# lower heat, cover and simmer 8 minutes.
# remove cover and top each chop with one quarter of the cheese.
# cover and simmer for an additional 2 minutes, until cheese melts.
# serve immediately.
# --------------------------------------------------------------------------------
#
# 🔹 Example 9
# Input: pears, pomegranate juice, pear nectar, sugar, grenadine, lemon juice
#
# Generated Recipe:
# pears with pomegranate juice ingredients: 1 lb pears, peeled and sliced 1 cup menned grenadine 1 cup lemon juice steps: preheat oven to 350°f. in a large bowl, combine the pears and berries. add the nectar, sugar, and lemon juice. stir in the lemon juice, and stir until the berries are ripe. pour the juice into a small bowl. place the ice cubes in the bottom of a baking dish. bake at 400°f for 30 minutes or until a toothpick inserted in the center comes out clean.
#
# True Recipe:
# pomegranate-pear sorbet
#
# ingredients:
# 2 pears, peeled and cut in half
# 4 cups pomegranate juice
# 1 1/3 cups pear nectar
# 1/2 cup sugar
# 3 tablespoons grenadine
# 1 tablespoon lemon juice
#
# steps:
# in a large saucepan, combine pears, pomegranate juice, pear nectar, and sugar.
# bring to a boil; decrease heat, and simmer 5 minutes or until sugar dissolves and pears are tender.
# remove from heat, and stir in grenadine and lemon juice.
# cover and chill at least 4 hours or until cold.
# remove and reserve pears from pomegranate mixture.
# place pomegranate mixture in the container of a 2-quart ice cream freezer; freeze according to the manufacturer's directions.
# slice reserved pears, and serve with sorbet.
# --------------------------------------------------------------------------------
#
# 🔹 Example 10
# Input: red onion, fat-free red wine vinaigrette, chickpeas, walnuts, toasted wheat germ, fresh parsley, eggs, curry powder, pepper, fat-free mayonnaise, dijon mustard, hamburger buns with sesame seeds, lettuce leaves, fresh basil leaves
#
# Generated Recipe:
# chickpeas salad ingredients: 1 large red onion, chopped 2 tablespoons fat-free red wine vinaigrette 1 large chikkeas, chopped 1 tablespoon walnuts, minced 1 teaspoon toasted wheat germ 1 teaspoon fresh parsley 2 eggs 1 teaspoon curry powder 1 teaspoon pepper 1 tablespoon fat-Free mayonnaise 1 teaspoon dijon mustard 2 large hamburger buns with sesame seeds 1 large lettuce leaves 1 tablespoon fresh basil leaves steps: preheat oven to 350°f. in a large skillet, saute onion, wine, and parsley. add eggs, curry powder, pepper, and mustard. cook until onions are tender, about 5 minutes. add parsley, eggs and curry powder and cook until browned. remove from heat and stir in parsley and eggs. add curry powder. stir in mustard. add lettuce leaves, basil and basil. cook on low for 10 minutes.
#
# True Recipe:
# chickpea and onion burgers
#
# ingredients:
# 1 large red onion, thinly sliced
# 1/4 cup fat-free red wine vinaigrette
# 2 (15 ounce) cans chickpeas, rinsed and drained
# 1/3 cup chopped walnuts
# 1/4 cup toasted wheat germ
# 1/4 cup fresh parsley
# 2 eggs
# 1 teaspoon curry powder
# 1/2 teaspoon pepper
# 1/3 cup fat-free mayonnaise
# 2 teaspoons dijon mustard
# 6 hamburger buns with sesame seeds
# 6 lettuce leaves
# 3 tablespoons fresh basil leaves, thinly sliced
#
# steps:
# combine onion and vinaigrette in small bowl and set aside. in food processor, combine chickpeas, walnuts, wheat germ and parsley; cover and pulse til blended. add eggs, curry, pepper; cover and process til smooth.
# shape into 6 patties. spray baking sheet with pam. bake at 375 for 10-15 minutes until firm.
# combine mayo and mustard, spread over buns. serve patties on buns, top with lettuce, basil and onion mixture.
# --------------------------------------------------------------------------------
#
# 🔹 Example 11
# Input: sunflower seeds, pumpkin seeds, dried cranberries, dried coconut, dehydrated apple, brazil nut
#
# Generated Recipe:
# cranberry &amp; coconut sprigs ingredients: 1 cup sunflower seeds 1 cup pumpkin seeds 2 tablespoons dried crainberries 1 cup dried coconut 1 cup dehydrated apple 1 cup brazil nut steps: preheat oven to 350°f. in a large bowl, combine sunflower seeds, pumpkin seeds, berries, coconut, apple, and nut. mix well. add nut mixture to a bowl. stir until well combined. add apple mixture to the bowl and stir well. serve.
#
# True Recipe:
# gluten free, dairy free trail mix
#
# ingredients:
# 1 cup raw sunflower seeds
# 1 1/2 cups roasted shelled pumpkin seeds
# 1 cup dried cranberries
# 1/2 cup dried coconut
# 1 cup dehydrated apple, chopped
# 1 cup brazil nut, roughly chopped
#
# steps:
# combine all ingredients.
# enjoy.
# --------------------------------------------------------------------------------
#
# 🔹 Example 12
# Input: butter, espresso powder, sugar, semi-sweet chocolate chips, eggs, kahlua
#
# Generated Recipe:
# kahlua chocolate chips ingredients: 2 tablespoons butter 1 teaspoon espresso powder 1 teaspoon sugar 1 cup semi-sweet chocolate chips 2 eggs 1 cup kalua steps: combine butter, espresso powder, sugar, chocolate chips and eggs in a large bowl. mix well. add eggs and mix well, stirring occasionally. stir well. serve warm.
#
# True Recipe:
# easy kahlua cuppuccino torte
#
# ingredients:
# 1 lb butter
# 2 tablespoons espresso powder
# 1/4 cup sugar (or more to suit taste)
# 1 lb semi-sweet chocolate chips
# 8 eggs
# 1/4 cup kahlua
#
# steps:
# set oven to 350 degrees.
# fit an 8-in square baking pan bottom with wax paper.
# grease the sides and the paper of baking pan.
# melt the butter.
# add expresso powder and sugar into the melted butter; stir well until dissolved.
# add the chocolate chips to the hot butter/expresso mixture; stir until chocolate is melted.
# beat in the 8 eggs, one at a time.
# stir in kahlua.
# pour the mixture into the prepared pan.
# place the pan into a larger baking pan, and fill the larger pan halfway to top of water (making a water bath).
# bake for 35 minutes.
# chill at least 8 hours before serving onto a serving platter.
# note: serve with pureed strawberries or raspberries or your favorite berry.
# --------------------------------------------------------------------------------
#
# 🔹 Example 13
# Input: mushroom, light cream cheese, panko breadcrumbs, parmesan cheese, dried rosemary, garlic powder, onion flakes, salt, pepper, olive oil
#
# Generated Recipe:
# mushroom &amp; panko breadcrumbs ingredients: 1 lb mushroom, peeled and sliced 1 cup light cream cheese, sliced 2 tablespoons panka breadcrumbs 1 tablespoon parmesan cheese 1 teaspoon dried rosemary 1 teaspoon garlic powder 1 teaspoon onion flakes 1 teaspoon salt 1 teaspoon pepper 1 tablespoon olive oil steps: preheat oven to 350°f. in a large bowl, combine cream cheese and pankok breadcrumbs. mix well. add breadcrumbs and garlic powder. stir in onion and salt and pepper. add olive oil and cook for 30 minutes or until cheese is melted. remove from heat and serve.
#
# True Recipe:
# lazy stuffed mushrooms
#
# ingredients:
# 1 lb mushroom, caps as large as possible
# 1/4 cup light cream cheese, garden vegetable flavor
# 1/2 cup panko breadcrumbs
# 1/4 cup parmesan cheese, shredded
# 1/4 teaspoon dried rosemary
# 1 teaspoon garlic powder
# 1 teaspoon onion flakes
# salt
# pepper
# olive oil
#
# steps:
# preheat the oven to 400 degrees.
# remove the stems from the mushrooms. place them into a food processor and process until finely minced.
# in a small bowl, mix the minced mushroom stems with the breadcrumbs, parmesan, rosemary, garlic and onion flakes. set aside for 5-10 minutes to allow the flavors to blend. 20 minutes is better if you have extra time, but it isn't necessary for the recipe to work.
# brush a baking sheet with olive oil, then place the mushroom caps onto the baking sheet, stem-side up.
# add cream cheese to each cap, adjusting the amount as needed depending on how large the caps are.
# sprinkle the mushroom stem mixture over the top of each mushroom, using a spoon to press it lightly into the cream cheese. this will help it stick.
# drizzle a little extra olive oil over the tops of the mushrooms. this will aid in browning.
# bake for 10 minutes or until the tops are golden brown and the cheese is heated through.
# --------------------------------------------------------------------------------
#
# 🔹 Example 14
# Input: potatoes, water, wheat flour, milk, sugar, oat milk, salt
#
# Generated Recipe:
# oat milk &amp; salt potatoes ingredients: 1 lb potatoes 1 cup water 1 cup wheat flour 1 cup milk 1 cup sugar 1 cup oaat milk salt steps: preheat oven to 350°f. in a large bowl, combine potatoes, water, flour, milk, sugar and sour cream. add salt and stir until well combined. add potatoes and stir to combine. add milk and sugar to mixture. stir in salt and mix well. serve warm.
#
# True Recipe:
# sweet potato casserole (imelletty perunalaatikko)
#
# ingredients:
# 2 kg potatoes
# to taste water
# 3 tablespoons wheat flour
# 1/2 liter milk
# 2 -3 tablespoons sugar
# 1 pinch oat milk, grated
# 1 tablespoon salt
#
# steps:
# peel potatoes.
# boil them until soft. mash them.
# add sugar and half of the flour and sprinkle the rest on top.
# place in a warm place covered with a cloth for an hour.
# add enough milk to get runny mixture. add nutmeg and salt pour in two casserole pots.
# bake in 175 c oven for an hour.
# --------------------------------------------------------------------------------
#
# 🔹 Example 15
# Input: lean ground beef, pinto beans, fat-free refried beans, green chilies, taco seasoning mix, flour tortillas, romaine lettuce, reduced-fat mexican cheese blend, tomatoes, salsa, reduced-fat sour cream
#
# Generated Recipe:
# romaine salad ingredients: 1 lb lean ground beef 1 pinto beans, sliced 1 cup fat-free refried beans 1 cup green chilies, chopped 2 tablespoons taco seasoning mix 1 cup flour tortillas, shredded 1 cup romime lettuce, chopped 1 cup reduced-fat mexican cheese blend 1 cup tomatoes, chopped 1/2 cup salsa, sour cream steps: preheat oven to 350°f. in a large bowl, combine beef, pinto, beans, green chilis, taco seasonsing mix, tortillas and tortillas. mix well. add tomatoes, salsa, and salsa. stir in salsa. add a pinch of salt and pepper to taste. serve.
#
# True Recipe:
# healthy bean chalupas
#
# ingredients:
# 1 lb lean ground beef
# 2 (16 ounce) cans pinto beans, undrained
# 1 (16 ounce) can fat-free refried beans
# 1 (4 1/2 ounce) can chopped green chilies
# 1 (1 1/4 ounce) package taco seasoning mix
# 8 (10 inch) flour tortillas
# shredded romaine lettuce
# 1 1/2 cups shredded reduced-fat mexican cheese blend
# 1 large tomatoes, diced
#
# salsa
# reduced-fat sour cream
#
# steps:
# brown ground beef in a large deep skillet, stirring to crumble.
# drain beef well, and set aside.
# wipe skillet clean.
# return beef to skillet; stir in beans, chiles, and seasoning mix.
# cook over medium-low heat, stirring often, until thoroughly heated.
# press each tortilla into a tortilla shell pan or 1-quart oven-safe bowl.
# bake at 375° for 8 to 10 minutes or until crisp.
# place on lettuce-lined serving plates.
# spoon bean mixture evenly into shells; sprinkle with cheese and diced tomato.
# serve with desired condiments.
# --------------------------------------------------------------------------------
#
# 🔹 Example 16
# Input: boneless skinless chicken breasts, extra virgin olive oil, poultry seasoning, salt %26 freshly ground black pepper, eggs, bacon, romaine lettuce hearts, lemons%2c juice of, avocados, tomatoes, red onion, white cheddar cheese
#
# Generated Recipe:
# chicken romaine salad ingredients: 2 boneless skinless chicken breasts 1 tablespoon extra virgin olive oil 2 tablespoons poultry seasoning salt & freshly ground black pepper 2 eggs 1 lb bacon, cut into thin strips 1 (14 ounce) can romine lettuce hearts 1 lemons, juice of 2 avocados, chopped 1 red onion, chopped 2 cups white cheddar cheese steps: preheat oven to 350°f. in a large bowl, combine the eggs, bacon, ricotta, lettuce hearts, lemons and juice of the avocados. add the tomatoes, onion, and cheddar cheese. stir in the cheese and cook until the cheese is melted. remove from the heat and add the cheese to the chicken and cook for about 5 minutes.
# 10 1/2 ounces potatoes
# 2 tablespoons vegetable oil
# 1 1/2 teaspoons cumin seeds
# seeds from 5 cardamom pod
# 1 1/2 teaspoons mustard seeds
# 2 onions, grated
# 1 teaspoon ground turmeric
# 1 teaspoon ground coriander
# 1 1/2 teaspoons chili powder
# 1 tablespoon fresh ginger, grated
# 2 large garlic cloves, crushed
# 1 1/4 cups strained tomatoes
# 1 cup vegetable stock
# 1 cup frozen green pea
# 4 ounces frozen spinach leaves
#
# 1 1/2 cups chickpea flour
# 1/2 teaspoon baking soda
# 1 3/4 cups water
# vegetable oil (for cooking)
#
# steps:
# to make the pancakes, sift the flour and baking soda into a large mixing bowl. make a well in the center and add the water. using a balloon whisk, gradually mix the flour into the water to form a smooth batter. add salt if preferred. let stand for 15 minutes. heat enough oil to cover the bottom of a skillet over medium heat. add a small quantity of batter to the skillet, and cook 3 minutes on each side until golden. repeat with remaining batter to make 8 pancakes.
# meanwhile, cut the carrots into chunks and the potatoes into fourths. place in a steamer and steam until just tender. heat the oil in a large pan over medium heat and fry the cumin, cardamom, and mustard seeds until they start to sizzle. add the onions, partially cover, and cook over medium-low heat, until soft and golden. add the other spices, ginger and garlic and cook stirring for 1 minute. add the strained tomatoes, stock, carrots and potatoes, partially cover, and cook for 10-15 minutes, or until the vegetables are tender. add the peas and spinach, then cook for 2-3 minutes. serve with the warm pancakes.
# --------------------------------------------------------------------------------
#
# 🔹 Example 18
# Input: sorghum flour, rice flour, tapioca flour, cornmeal, baking powder, salt, sugar, xanthan gum, butter, eggs, buttermilk, butter
#
# Generated Recipe:
# sorghum pancakes ingredients: 1 cup lukhum flour 1 cup rice flour 1/2 cup tapioca flour 1 1/2 cups cornmeal 1 teaspoon baking powder 1 teaspoon salt 1 teaspoon sugar 1 teaspoon xanthan gum 1 cup butter, melted 1 cup eggs 1 tablespoon buttermilk 1/2 cup butter steps: preheat oven to 350°f. in a large bowl, combine flour, rice flour, cornmeals, baking powder, salt and sugar. add sugar. stir until well combined. add buttermilk, eggs, buttermilk and buttermilk. mix well. bake at 350° for 30 minutes or until golden brown.
#
# True Recipe:
# gluten free cornbread
#
# ingredients:
# 1/4 cup sorghum flour
# 1/4 cup rice flour
# 1/2 cup tapioca flour
# 1 cup cornmeal
# 3 1/2 teaspoons baking powder
# 3/4 teaspoon salt
# 3 tablespoons sugar
# 1 teaspoon xanthan gum
# 1/4 cup butter
# 2 large eggs
# 1 cup buttermilk
# 3 tablespoons butter (for skillet)
#
# steps:
# preheat oven to 425. add cast iron skillet to oven while it heats up and you mix the ingredients.
# mix dry ingredients together in a bowl.
# add butter in pats and blend with dry ingredients as if you were making pie crust. (i use my hands to cut it in.).
# add the eggs and buttermilk.
# mix with fork just until blended.
# take skillet out of the hot oven and add 3 tbsp of butter and let it melt.
# pour batter over the hot butter.
# return to oven and bake for 20 minutes.
# once done, flip onto a plate for serving (upside down).
# (note: the top won't brown very well but you will never know this once you flip it.).
# --------------------------------------------------------------------------------
#
# 🔹 Example 19
# Input: vegetable oil, boneless skinless chicken breast halves, campbell%27s cream of chicken soup, water, paprika, pepper, minute white rice, frozen broccoli florets
#
# Generated Recipe:
# chicken fried chicken ingredients: 2 tablespoons vegetable oil 2 boneless skinless chicken breast halves 1 cup campbell's cream of chicken soup 1 cup water 1 teaspoon paprika 1 teaspoon pepper 1 cup minute white rice 1 cup frozen broccoli florets steps: preheat oven to 350°f. in a large bowl, combine the oil, chicken breasts, and campbells soup. add water, paprica, and pepper. add the chicken broth, and cook until the chicken is tender, about 5 minutes. add rice and cook for 5 minutes, or until rice is tender and tender. remove chicken from heat and stir in the broccoli and broccoli. place chicken on a baking sheet and bake for 30 minutes or until broccoli is tender.
#
# True Recipe:
# campbell's 15-minute chicken, broccoli &amp; rice dinner
#
# ingredients:
# 1 tablespoon vegetable oil
# 4 boneless skinless chicken breast halves
# 1 (10 3/4 ounce) can campbell's cream of chicken soup or 1 (10 3/4 ounce) can 98% fat-free cream of chicken soup
# 1 1/2 cups water
# 1/4 teaspoon paprika
# 1/4 teaspoon pepper
# 2 cups minute white rice, uncooked
# 2 cups fresh frozen broccoli florets or 2 cups fresh frozen broccoli florets
#
# steps:
# heat oil in skillet.
# add chicken and cook until browned.
# remove chicken.
# add soup, water, paprika and pepper; stir.
# heat to a boil.
# stir in rice and broccoli.
# top with chicken.
# season chicken with additional paprika and pepper.
# cover and cook over low heat 5 minute.
# or until done.
# --------------------------------------------------------------------------------
#
# 🔹 Example 20
# Input: ground beef, red enchilada sauce, mexican blend cheese, cheddar cheese, flour tortillas
#
# Generated Recipe:
# beef enchilada sauce ingredients: 1 lb ground beef 2 tablespoons red enchina sauce 1 tablespoon mexican blend cheese 1 tablespoon cheddar cheese 1 cup flour tortillas steps: preheat oven to 350°f. in a large bowl, combine the beef, e.g., red sauce, cheese, cheddar cheese, and flour tortilla. add the flour tortilla and mix well. stir in the tortillas. place on a baking sheet and bake for 30 minutes.
#
# True Recipe:
# easy cheesy ground beef enchiladas
#
# ingredients:
# 1 lb ground beef
# 2 (10 ounce) cans red enchilada sauce
# 8 ounces shredded mexican blend cheese
# 8 ounces shredded cheddar cheese
# 12 (6 inch) flour tortillas
#
# steps:
# heat oven to 375°. brown ground beef until thoroughly cooked; drain.
# stir in 3/4 cup enchilada sauce and one cup of cheese.
# spoon meat mixture onto tortillas roll-up and place seam-side down in lightly greased baking dish.
# pour remaining enchilada sauce over top. cover with remaining cheese.
# bake for 15 to 20 minutes or until cheese melts.
# serve with yellow rice and refried beans.
# garnish with sour cream, salsa, and lettuce.
# --------------------------------------------------------------------------------
#
# 🔹 Example 21
# Input: butter, granulated sugar, eggs, pumpkin, milk, all-purpose flour, baking soda, salt, baking powder, cinnamon, nutmeg, clove, nuts, raisins, confectioners%27 sugar, ground cinnamon, ground nutmeg, milk
#
# Generated Recipe:
# pumpkin pie ingredients: 1 cup butter 1 cup granulated sugar 2 eggs 1 cup pumpkin 1 cup milk 2 tablespoons all-purpose flour 1 teaspoon baking soda 1/2 teaspoon salt 1/2 teaspoon baking powder 1 teaspoon cinnamon 1 teaspoon nutmeg 1 clove 1 cup nuts 1 cup raisins 1 cup confectioners' sugar 1 teaspoon ground cinnamon 2 teaspoons ground nutmelg 1/2 cup milk steps: in a large bowl, combine butter, sugar, eggs, pumpkin, milk, flour, baking soda, salt, baking powder, cinnamon, nutmesg, clove, nuts, raisins, confectioners’ sugar, ground cinnamon, ground nuts, nuts and raisins. stir in milk. beat in butter and sugar until smooth. add eggs and mix well. add pumpkin and milk and beat until well combined. add flour mixture and beat well. beat until combined. mix in raisins and confectionerss sugar and cinnamon. beat well to combine.
#
# True Recipe:
# spiced pumpkin bread
#
# ingredients:
# 2/3 cup butter, softened
# 2 2/3 cups granulated sugar
# 4 eggs
# 1 (16 ounce) can pumpkin
# 2/3 cup milk
# 3 1/3 cups all-purpose flour
# 2 teaspoons baking soda
# 1 1/2 teaspoons salt
# 1/2 teaspoon baking powder
# 1 1/2 teaspoons cinnamon
# 1/2 teaspoon nutmeg
# 1/2 teaspoon clove
# 3/4 cup chopped nuts (i like walnuts)
# 3/4 cup raisins
#
# 1/2 cup confectioners' sugar
# 1/8 teaspoon ground cinnamon
# 1/8 teaspoon ground nutmeg
# 2 -3 teaspoons milk
#
# steps:
# prehat oven to 350 f.
# grease bottoms of 2 loaf pans.
# cream together butter and sugar in a large bowl.
# add the eggs, pumpkin, and milk.
# stir in the flour, baking soda, salt, baking powder, cinnamon, nutmeg, and cloves.
# do not overmix.
# fold in the raisins and nuts.
# divide batter evenly between the two loaf pans.
# bake until a toothpick inserted in the center comes out clean, about 65-70 minutes.
# cool slightly, then loosen sides of pan and invert loaf to remove.
# allow to cool on a wire rack.
# while bread is cooling, prepare glaze.
# mix confectioners sugar together with the cinnamon and nutmeg and just enough milk to form a drizzling consistency.
# drizzle glaze over loaves.
# slice loaves and serve when cool.
# to store unused portions, wrap and refrigerate for no longer than 10 days.
# --------------------------------------------------------------------------------
#
# 🔹 Example 22
# Input: brown sugar, fat, eggs, vanilla, nuts, sugar, salt, cinnamon, orange extract, flour
#
# Generated Recipe:
# brown sugar muffins ingredients: 1 cup brown sugar 1 cup fat 2 eggs 1 teaspoon vanilla 1 cup nuts 1 cup sugar 1 teaspoon salt 1 teaspoon cinnamon 1 teaspoon orange extract 1 cup flour steps: preheat oven to 350°f. in a large bowl, combine sugar, fat, eggs, vanilla, nuts, sugar, salt, cinnamon, orange extract and flour. mix well. add flour and stir until well combined. stir in flour. bake at 400°f for 10 minutes.
#
# True Recipe:
# aunt stella's ice box cookies
#
# ingredients:
# 1 cup brown sugar
# 1 1/2 cups fat (or 3/4 cup butter or margarine & 3/4 cup crisco)
# 3 eggs, beaten
# 2 teaspoons vanilla
# 1 1/4 cups nuts, chopped
# 1 cup sugar
# 1 teaspoon salt
# 1 teaspoon cinnamon
# 1/2 teaspoon orange extract
# 4 cups flour
#
# steps:
# beat fat and sugars until creamy; add eggs and vanilla, and beat until well mixed.
# add remaining ingredients and mix well.
# divide dough into two long rolls, and place in a narrow pan in the freezer to chill overnight.
# pre-heat oven to 375°f.
# slice very thin and bake on an ungreased cookie sheet at 375°f for 8-10 minutes.
# remove from pan to cool.
# --------------------------------------------------------------------------------
#
# 🔹 Example 23
# Input: red bell pepper, mayonnaise, capers, flat leaf parsley, fresh lemon juice, salt %26 freshly ground black pepper
#
# Generated Recipe:
# bell pepper mayonnaise ingredients: 1 lb red bell pepper, sliced 1 tablespoon Mayonnaise 1 cup capers 1 cup flat leaf parsley 1 tablespoon fresh lemon juice salt & freshly ground black pepper steps: preheat oven to 350°f. in a large bowl, combine peppers, capers, parsley, lemon juice, salt and pepper. stir in peppers. add lemon juice and salt to taste. serve.
#
# True Recipe:
# roasted pepper-caper aioli
#
# ingredients:
# 1 red bell pepper
# 1/2 cup mayonnaise
# 2 tablespoons drained capers
# 2 tablespoons chopped flat leaf parsley
# 1 teaspoon fresh lemon juice
# salt & freshly ground black pepper
#
# steps:
# roast the pepper under the broiler, until charred all over, about 8 minutes. move to a bowl, cover with plastic wrap and let steam for 5 minutes. peel and finely chop the pepper.
# in a small bowl, mix the roasted pepper with the mayonnaise, capers, parsley and lemon juice. season with salt and pepper. serve and enjoy.
# the aioli can be refrigerated for up to 3 days.
# --------------------------------------------------------------------------------
#
# 🔹 Example 24
# Input: cream cheese, sugar, vanilla, nutmeg, strawberry, whipping cream, icing sugar, 9-inch graham cracker crust
#
# Generated Recipe:
# strawberry graham cracker crust ingredients: 1 cup cream cheese 1 cup sugar 1 teaspoon vanilla 1 teaspoon nutmeg 1 cup strawberry, sliced 1 cup whipping cream 1 tablespoon icing sugar 1 1/2 cups 9-inch Graham crackers crust steps: preheat oven to 350°f. in a large mixing bowl, combine cream cheese, sugar, vanilla, and nutsmeg. mix in strawberries. mix until smooth. add cream cheese and ice cream. mix well. bake at 350° for 10 minutes.
#
# True Recipe:
# strawberry pie
#
# ingredients:
# 1 (8 ounce) package cream cheese
# 1/4 cup sugar
# 1/2 teaspoon vanilla
# 1 dash nutmeg
# 1 cup strawberry, sliced
# 1 cup whipping cream
# 1/4 cup icing sugar
# 1 9-inch graham cracker crust
#
# steps:
# combine cheese, sugar, vanilla, nutmeg and blend well.
# mash 3/4 cup strawberry slices and stir into cheese mixture.
# whip cream with icing sugar until stiff peaks form.
# fold into cheese mixture.
# fold in remaining strawberry slices.
# spoon into crust and chill a few hours or overnight.
# garnish with extra berries if desired.
# --------------------------------------------------------------------------------
#
# 🔹 Example 25
# Input: sweetened condensed milk, evaporated milk, eggs, sugar, vanilla extract, almond extract, dark chocolate, cinnamon stick, sugar
#
# Generated Recipe:
# chocolate cake ingredients: 1 cup sweetened condensed milk 1 cup evaporated milk 2 eggs 1 teaspoon sugar 1 teaspoon vanilla extract 1 teaspoon almond extract 1 cup dark chocolate 1 teaspoon cinnamon stick 1 cup sugar steps: preheat oven to 350°f. in a large bowl, combine milk, eggs, sugar, vanilla extract, almond extract, dark chocolate, cinnamon stick, sugar and sugar. mix well. stir in chocolate and cinnamon stick. add sugar and stir until well combined. pour into a greased baking dish. bake at 400°f for 30 minutes.
#
# True Recipe:
# dark chocolate flan
#
# ingredients:
# 1 (12 ounce) can sweetened condensed milk
# 1 (12 ounce) can evaporated milk
# 6 eggs
# 1/2 cup sugar
# 1/2 teaspoon vanilla extract
# 1/2 teaspoon almond extract
# 4 ounces premium dark chocolate, shaved thin
# 1 cinnamon stick
#
# 1 cup sugar
#
# steps:
# make caramel by slowly heating the sugar in a small saucepan until golden and liquid. be careful not to stir too much, as this will cause crystals to form. pour the very hot, molten sugar into the flan mold (this can either be a round pan or a bundt pan - i usually use a bundt pan because i like the pretty pattern the flan takes). be sure to tilt the mold so that the caramel coats the sides.
# in a small saucepan, heat the milk, cinnamon, and chocolate pieces, stirring occasionally to help the chocolate melt. let this cool down to just warm and remove the cinnamon stick. blend the rest of the ingredients together gradually adding the milk mixture.
# preheat oven to 350°f.
# pour into caramelized pan and bake in a hot water bath (bain marie) for about 50-55 minutes or until golden. test with a knife or toothpick, it should come out clean. remove from oven, cool, unmold and serve. (if you are having trouble unmolding the flan, run a small, sharp knife around sides of pan to help release.).
# --------------------------------------------------------------------------------
#
# 🔹 Example 26
# Input: butter, all-purpose flour, salt, pepper, milk, egg yolks, parmesan cheese, egg whites, cream of tartar, frozen chopped spinach, fresh mushrooms, onion, butter, cream cheese, dijon mustard, ground nutmeg
#
# Generated Recipe:
# spinach &amp; spinach dip ingredients: 2 tablespoons butter 1 1/2 tablespoons all-purpose flour 1/2 teaspoon salt 1/2 teaspoon pepper 1 cup milk 1 egg yolks 1 cup parmesan cheese 1 egg whites 1 tablespoon cream of tartar 1 cup frozen chopped spinach 1 cup fresh mushrooms 1 onion 1 tablespoon butter 1 cup cream cheese 1 teaspoon dijon mustard 1 teaspoon ground nutmeg steps: preheat oven to 350°f. in a large bowl, combine butter, flour, salt, pepper, milk and egg yolk mixture. add milk and mix well. stir in eggs and yolks. add cream cheese, cream cheese and mustard. beat until smooth. add mushrooms, onion, butter and cream cheese. beat well. add in cream cheese mixture, mustard and nut-meg. stir well.
#
# True Recipe:
# spinach-mushroom souffle roll
#
# ingredients:
# 1/4 cup butter or 1/4 cup margarine
# 1/2 cup all-purpose flour
# 1/2 teaspoon salt
# 1 dash pepper
# 2 cups milk
# 6 egg yolks
# 1/4 cup grated parmesan cheese
# 6 egg whites
# 1/4 teaspoon cream of tartar
# 1 (10 ounce) package frozen chopped spinach, cooked and drained well
# 1/2 cup fresh mushrooms, sliced
# 1 tablespoon onion, finely chopped
# 1 tablespoon butter or 1 tablespoon margarine
# 3 ounces cream cheese, softened
# 1 tablespoon dijon mustard
# 1/4 teaspoon ground nutmeg
#
# steps:
# line a 15 x 10 x 1" baking pan with foil, extending foil 1" beyond edges of pan.
# grease and lightly flour; set aside melt the butter.
# stir in the 1/2 cup flour, salt, and pepper.
# add milk all at once.
# cook and stir till thickened and bubbly.
# cook and stir 1 minute more.
# remove from heat beat the egg yolks till thick and lemon colored.
# slowly stir thickened milk mixture and parmesan cheese into beaten egg yolks.
# using clean beaters, beat egg whites and cream of tartar till stiff peaks form.
# fold a small amount of the beaten egg whites into egg yolk mix.
# fold egg yolk mixture into remaining egg whites; spread in prepared pan.
# bake in a 375°f oven about 20 minutes.
# while that's cooking cook the frozen chopped spinach and squeeze it dry.
# meanwhile, cook the mushrooms and onion in 1 tbs butter till tender but not browned.
# stir in the spinach, softened cream cheese, dijon mustard and nutmeg.
# heat through, stirring occasional.
# immediately loosen the soufflé from pan when puffed and slightly set; turn out onto foil.
# spread spinach mushroom filling over souffle to within 1/2" of the edge.
# use foil to start rolling up soufflé jelly roll style, beginning with one of the short sides.
# slice; serve immediately.
# --------------------------------------------------------------------------------
#
# 🔹 Example 27
# Input: banana, skim milk, quick-cooking oatmeal, creamy peanut butter
#
# Generated Recipe:
# banana pancakes ingredients: 1 lb banana 1 cup skim milk 1 cup quick-cooking oatmeal 2 tablespoons creamy peanut butter steps: preheat oven to 350°f. in a large bowl, combine banana, milk, oatmeal, peanut butter, and peanut butter. mix well. stir in peanut butter and stir until well combined.
#
# True Recipe:
# banana oatmeal
#
# ingredients:
# 1 large banana, ripe
# 1/2 cup skim milk
# 1/2 cup quick-cooking oatmeal
# 1 tablespoon creamy peanut butter
#
# steps:
# break banana into chunks and put into a small blender jar.
# add the skim milk.
# liquify in blender.
# put the dry oatmeal in a microwave safe bowl. (if you want to mix it ahead of time, use a small microwave safe dish which has a lid).
# pour the banana mixture on top of the oatmeal.
# stir well, to incorporate all the oatmeal.
# microwave (uncovered) on high setting for 90 seconds.
# stir.
# microwave again for about 90 seconds.
# if it starts to rise over the top of the bowl, stop the cooking, because it is most likely already done!
# stir in peanut butter.
# --------------------------------------------------------------------------------
#
# 🔹 Example 28
# Input: chicken broth, cornstarch, soy sauce, vegetable oil, asparagus, gingerroot, garlic, crushed red pepper flakes
#
# Generated Recipe:
# asparagus &amp; ginger salad ingredients: 1 1/2 cups chicken broth 1 tablespoon cornstarch 1 tablespoon soy sauce 1 tablespoon vegetable oil 1 lb asparagus, chopped 1 teaspoon gingerroot 1 garlic, chopped crushed red pepper flakes steps: preheat oven to 350°f. in a large bowl, combine chicken broth, corn starch, soy and soy Sauce. add vegetable oil, asparagus, gingerroot, garlic, and red pepper. mix well. add garlic, pepper and flakes. add to chicken mixture. cook for 30 minutes or until chicken is tender.
#
# True Recipe:
# asparagus stir-fry
#
# ingredients:
# 1 cup chicken broth
# 1 tablespoon cornstarch
# 1 tablespoon soy sauce
# 1 tablespoon vegetable oil
# 1 lb asparagus, trimmed and cut into 2 inch diagonal pieces
# 2 teaspoons fresh grated gingerroot
# 3 cloves garlic, minced
# crushed red pepper flakes, to taste
#
# steps:
# in a small bowl, add the broth, cornstarch, and soy sauce; stir to combine.
# in a large skillet, add the oil; heat over high heat.
# add the asparagus, gingerroot, garlic, and crushed red pepper flakes; stir-fry for a few minutes or until almost crisp-tender.
# add in the broth mixture; bring to a boil, stirring frequently.
# stir and continue cooking until sauce is thickened.
# serve hot over hot cooked rice.
# --------------------------------------------------------------------------------
#
# 🔹 Example 29
# Input: ears of corn, bacon, red onion, jalapeno, garlic clove, flour, salt, ground black pepper, red potatoes, chicken broth, half-and-half, tomatoes, fresh basil leaf
#
# Generated Recipe:
# bacon &amp; bacon casserole ingredients: 2 ears of corn 1 lb bacon 1 red onion 1 jalapeno 1 garlic clove 1 teaspoon flour 1/2 teaspoon salt 1/2 teaspoon ground black pepper 2 lbs red potatoes 1 1/2 cups chicken broth 1/2 cup half-and-half 2 tomatoes 1/2 teaspoon fresh basil leaf steps: preheat oven to 350°f. in a large bowl, combine corn, bacon, onion, jalapenos, garlic, flour, salt, and black pepper. add potatoes, chicken broth, half and half, tomatoes, basil leaf, tomatoes and basil leaf. add to casserole. cover and bake for 30 minutes or until potatoes are tender.
#
# True Recipe:
# bacon-corn chowder
#
# ingredients:
# 6 medium ears of corn, husks and silks removed
# 4 slices bacon, cut into 1/2-inch pieces
# 1 medium red onion, chopped
# 1 jalapeno, seeded and finely chopped
# 1 garlic clove, finely chopped
# 2 tablespoons flour
# 1/2 teaspoon salt
# 1/8 teaspoon ground black pepper
# 1 lb red potatoes, cut into 1/2-inch pieces (6 medium)
# 29 ounces chicken broth
# 2 cups half-and-half
# 1 medium ripe tomatoes, peeled, seeded, and chopped
# thinly sliced fresh basil leaf
#
# steps:
# cut kernels from corncobs(about 3 cups), reserving 3 corncobs. discard remaining corncobs.
# in a 5-quart dutch oven, cook bacon over medium heat until browned. with slotted spoon, transfer bacon to paper towels to drain and crumble. to bacon drippings in dutch oven, add onion and jalapeno and cook stirring until onion is tender (about 5 minutes). add garlic and cook 1 minute longer.
# with wire whisk, whisk in flour, salt, and pepper. cook stirring for 1 minute longer. stir in potatoes, corncobs, broth, and half and half. heat to boiling over high heat. reduce heat and cover and simmer until potatoes are tender (10 to 15 minutes).
# discard corncobs and stir in corn kernels and heat through. ladle chowder into tureen. stir in tomato and sprinkle with bacon and basil.
# --------------------------------------------------------------------------------
#
# 🔹 Example 30
# Input: all-purpose flour, yellow cornmeal, sugar, baking soda, baking powder, salt, fresh basil, fresh oregano, fresh thyme, eggs, condensed tomato soup, unsalted butter, lemon juice, parmigiano-reggiano cheese
#
# Generated Recipe:
# chinese condensed tomato soup ingredients: 1 1/2 cups all-purpose flour 1 cup yellow cornmeal 1 cup sugar 1 teaspoon baking soda 1 tablespoon baking powder 1 teaspoon salt 2 tablespoons fresh basil 1 tablespoon fresh oregano 1 teaspoon fresh thyme 1 cup eggs 1 1/2 ounces condered tomato soup 1 cup unsalted butter 1 tablespoon lemon juice 1 cup parmigiano-reggiano cheese steps: in a large bowl, combine flour, cornmeals, sugar, baking soda, baking powder, salt, and basil. mix well. stir in basil, oreggano, and tyme. add eggs and stir until well combined. add butter, lemon juice, and parmiano cheese. add to soup mixture and stir well. add parmo and cheese. stir well and serve.
#
# True Recipe:
# herbed tomato muffins
#
# ingredients:
# 2 cups all-purpose flour
# 1/4 cup yellow cornmeal or 1/4 cup white cornmeal
# 1/4 cup sugar
# 2 teaspoons baking soda
# 1 teaspoon baking powder
# 1/2 teaspoon salt
# 2 teaspoons chopped fresh basil
# 2 teaspoons chopped fresh oregano
# 1 teaspoon fresh thyme
# 2 large eggs, at room temperature
# 1 (10 3/4 ounce) can condensed tomato soup
# 8 tablespoons unsalted butter, melted and cooled
# 2 teaspoons lemon juice
# 1/4 cup grated parmigiano-reggiano cheese
#
# steps:
# preheat the oven to 400 degrees and place the rack in the center of the oven.
# add flour, cornmeal, sugar, baking soda, baking powder, salt, basil, oregano, and thyme to a mixing bowl; whisk until well combined; set aside.
# in a large mixing bowl, whisk eggs until lightly beaten; whisk in the tomato soup, melted butter, and lemon juice.
# stir in the cheese; then add the flour mixture, stirring just until moistened but of a uniform color (do no overmix).
# fill muffin tins that have been sprayed with nonstick cooking spray 3/4 full with batter.
# bake for 18 minutes or until muffins have bumpy, rounded tops and pick comes out clean.
# place pan on a wire rack; let cool for 10 minutes.
# turn muffins out of pan; cool 5 more mintesu on the rack before serving.
# to store or freeze muffins, let them cool completely before sealing an airtight container or freezer-safe bags.
# **cheddar tomato muffins--omit the herbs; substitute shredded cheddar cheese for the parmigiano-reggiano.
# **chunky tomato muffins--omit the herbs; add 1/2 cup marinated sun-dried tomatoes, drained and chopped, with the cheese.
# **olive tomato muffins--omit the herbs; add 1/2 cup sliced pitted olives (green or black) with the cheese.
# **tomato muffins--omit the herbs.
# --------------------------------------------------------------------------------

# %% [markdown]
# # 4. Ablation Studies (FLAN-T5)

# %%
# Sample size for ablation
ABLATION_SAMPLE_SIZE = 100
np.random.seed(42)
sample_indices = np.random.choice(len(test_dataset), size=ABLATION_SAMPLE_SIZE, replace=False)

# Define different prompt formats
prompt_formats = {
    "format_0": "Generate a recipe with measurements using: {ingredients}" # original
    "format_1": "Create a recipe with ingredient measurements using: {ingredients}", # synonym + measurement emphasis
    "format_2": "Given the ingredients {ingredients}, write a complete recipe including quantities and steps.", # explicit structure
    "format_3": "You are a chef. Develop a detailed recipe with exact measurements for: {ingredients}", # persona + precision
    "format_4": "From these ingredients: {ingredients}, plan and write a step-by-step recipe including measurements." # reasoning cue + step structure
}

# Generate recipes using specific prompt format
def generate_with_prompt(ingredients, prompt_template, model, tokenizer):
    # Format the prompt
    prompt = prompt_template.format(ingredients=ingredients)

    # Tokenise
    inputs = tokenizer(
        prompt,
        return_tensors="pt",
        max_length=128,
        truncation=True
    )

    # Move inputs to same device as model
    device = next(model.parameters()).device
    inputs = {k: v.to(device) for k, v in inputs.items()}

    # Generate
    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_length=256,
            num_beams=4,
            early_stopping=True,
            no_repeat_ngram_size=3,
            temperature=0.7,
        )

    return tokenizer.decode(outputs[0], skip_special_tokens=True)

prompt_results = {}

for format_name, prompt_template in prompt_formats.items():
    print(f"\nTesting {format_name}: '{prompt_template}'")

    generations = []
    references = []
    coverages = []

    for idx in tqdm(sample_indices, desc=f"Generating with {format_name}"):
        input_text = test_dataset[int(idx)]['input_text']
        reference = test_dataset[int(idx)]['target_text']

        # Extract just ingredients
        if "using:" in input_text.lower():
            ingredients = input_text.split("using:")[-1].strip()
        else:
            ingredients = input_text

        # Generate
        generated = generate_with_prompt(ingredients, prompt_template, model, tokenizer)

        generations.append(generated)
        references.append(reference)

        # Calculate metrics
        coverage = ingredient_coverage(generated, ingredients)
        coverages.append(coverage)

    # Calculate BERTScore
    print(f"  Computing BERTScore...")
    P, R, F1 = bert_score(generations, references, lang="en", verbose=False, batch_size=32)

    prompt_results[format_name] = {
        'prompt': prompt_template,
        'bertscore_f1': F1.mean().item(),
        'coverage': np.mean(coverages)
    }

    print(f"Results: BERTScore F1={F1.mean():.4f}, Ingredient Coverage={np.mean(coverages):.2%}")

# Create comparison table
ablation_df = pd.DataFrame(prompt_results).T
ablation_df = ablation_df.round(4)
print(ablation_df.to_string())

# %% [markdown]
# # 5. Model building (Retriever)
# Use fine-tuned t5 model with the adaptor to use it as a feature extractor

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Path to your saved adapter folder
model_dir = "/content/drive/MyDrive/recipe_model/final_model"

# Load adapter config
config = PeftConfig.from_pretrained(model_dir)

# Load base model
base_model = T5ForConditionalGeneration.from_pretrained(config.base_model_name_or_path)

# Load the fine-tuned LoRA adapter weights
model = PeftModel.from_pretrained(base_model, model_dir)

# Load tokenizer
tokenizer = T5Tokenizer.from_pretrained(model_dir)

device = "cuda" if torch.cuda.is_available() else "cpu"
model = model.to(device)
model.eval()
# Out:
# PeftModelForSeq2SeqLM(
#   (base_model): LoraModel(
#     (model): T5ForConditionalGeneration(
#       (shared): Embedding(32128, 512)
#       (encoder): T5Stack(
#         (embed_tokens): Embedding(32128, 512)
#         (block): ModuleList(
#           (0): T5Block(
#             (layer): ModuleList(
#               (0): T5LayerSelfAttention(
#                 (SelfAttention): T5Attention(
#                   (q): lora.Linear(
#                     (base_layer): Linear(in_features=512, out_features=384, bias=False)
#                     (lora_dropout): ModuleDict(
#                       (default): Dropout(p=0.1, inplace=False)
#                     )
#                     (lora_A): ModuleDict(
#                       (default): Linear(in_features=512, out_features=16, bias=False)
#                     )
#                     (lora_B): ModuleDict(
#                       (default): Linear(in_features=16, out_features=384, bias=False)
#                     )
#                     (lora_embedding_A): ParameterDict()
#                     (lora_embedding_B): ParameterDict()
#                     (lora_magnitude_vector): ModuleDict()
#                   )
#                   (k): lora.Linear(
#                     (base_layer): Linear(in_features=512, out_features=384, bias=False)
#                     (lora_dropout): ModuleDict(
#                       (default): Dropout(p=0.1, inplace=False)
#                     )
#                     (lora_A): ModuleDict(
#                       (default): Linear(in_features=512, out_features=16, bias=False)
#                     )
#                     (lora_B): ModuleDict(
#                       (default): Linear(in_features=16, out_features=384, bias=False)
#                     )
#                     (lora_embedding_A): ParameterDict()
#                     (lora_embedding_B): ParameterDict()
#                     (lora_magnitude_vector): ModuleDict()
#                   )
#                   (v): lora.Linear(
#                     (base_layer): Linear(in_features=512, out_features=384, bias=False)
#                     (lora_dropout): ModuleDict(
#                       (default): Dropout(p=0.1, inplace=False)
#                     )
#                     (lora_A): ModuleDict(
#                       (default): Linear(in_features=512, out_features=16, bias=False)
#                     )
#                     (lora_B): ModuleDict(
#                       (default): Linear(in_features=16, out_features=384, bias=False)
#                     )
#                     (lora_embedding_A): ParameterDict()
#                     (lora_embedding_B): ParameterDict()
#                     (lora_magnitude_vector): ModuleDict()
#                   )
#                   (o): lora.Linear(
#                     (base_layer): Linear(in_features=384, out_features=512, bias=False)
#                     (lora_dropout): ModuleDict(
#                       (default): Dropout(p=0.1, inplace=False)
#                     )
#                     (lora_A): ModuleDict(
#                       (default): Linear(in_features=384, out_features=16, bias=False)
#                     )
#                     (lora_B): ModuleDict(
#                       (default): Linear(in_features=16, out_features=512, bias=False)
#                     )
#                     (lora_embedding_A): ParameterDict()
#                     (lora_embedding_B): ParameterDict()
#                     (lora_magnitude_vector): ModuleDict()
#                   )
#                   (relative_attention_bias): Embedding(32, 6)
#                 )
#                 (layer_norm): T5LayerNorm()
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (1): T5LayerFF(
#                 (DenseReluDense): T5DenseGatedActDense(
#                   (wi_0): Linear(in_features=512, out_features=1024, bias=False)
#                   (wi_1): Linear(in_features=512, out_features=1024, bias=False)
#                   (wo): Linear(in_features=1024, out_features=512, bias=False)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                   (act): NewGELUActivation()
#                 )
#                 (layer_norm): T5LayerNorm()
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#           )
#           (1-7): 7 x T5Block(
#             (layer): ModuleList(
#               (0): T5LayerSelfAttention(
#                 (SelfAttention): T5Attention(
#                   (q): lora.Linear(
#                     (base_layer): Linear(in_features=512, out_features=384, bias=False)
#                     (lora_dropout): ModuleDict(
#                       (default): Dropout(p=0.1, inplace=False)
#                     )
#                     (lora_A): ModuleDict(
#                       (default): Linear(in_features=512, out_features=16, bias=False)
#                     )
#                     (lora_B): ModuleDict(
#                       (default): Linear(in_features=16, out_features=384, bias=False)
#                     )
#                     (lora_embedding_A): ParameterDict()
#                     (lora_embedding_B): ParameterDict()
#                     (lora_magnitude_vector): ModuleDict()
#                   )
#                   (k): lora.Linear(
#                     (base_layer): Linear(in_features=512, out_features=384, bias=False)
#                     (lora_dropout): ModuleDict(
#                       (default): Dropout(p=0.1, inplace=False)
#                     )
#                     (lora_A): ModuleDict(
#                       (default): Linear(in_features=512, out_features=16, bias=False)
#                     )
#                     (lora_B): ModuleDict(
#                       (default): Linear(in_features=16, out_features=384, bias=False)
#                     )
#                     (lora_embedding_A): ParameterDict()
#                     (lora_embedding_B): ParameterDict()
#                     (lora_magnitude_vector): ModuleDict()
#                   )
#                   (v): lora.Linear(
#                     (base_layer): Linear(in_features=512, out_features=384, bias=False)
#                     (lora_dropout): ModuleDict(
#                       (default): Dropout(p=0.1, inplace=False)
#                     )
#                     (lora_A): ModuleDict(
#                       (default): Linear(in_features=512, out_features=16, bias=False)
#                     )
#                     (lora_B): ModuleDict(
#                       (default): Linear(in_features=16, out_features=384, bias=False)
#                     )
#                     (lora_embedding_A): ParameterDict()
#                     (lora_embedding_B): ParameterDict()
#                     (lora_magnitude_vector): ModuleDict()
#                   )
#                   (o): lora.Linear(
#                     (base_layer): Linear(in_features=384, out_features=512, bias=False)
#                     (lora_dropout): ModuleDict(
#                       (default): Dropout(p=0.1, inplace=False)
#                     )
#                     (lora_A): ModuleDict(
#                       (default): Linear(in_features=384, out_features=16, bias=False)
#                     )
#                     (lora_B): ModuleDict(
#                       (default): Linear(in_features=16, out_features=512, bias=False)
#                     )
#                     (lora_embedding_A): ParameterDict()
#                     (lora_embedding_B): ParameterDict()
#                     (lora_magnitude_vector): ModuleDict()
#                   )
#                 )
#                 (layer_norm): T5LayerNorm()
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (1): T5LayerFF(
#                 (DenseReluDense): T5DenseGatedActDense(
#                   (wi_0): Linear(in_features=512, out_features=1024, bias=False)
#                   (wi_1): Linear(in_features=512, out_features=1024, bias=False)
#                   (wo): Linear(in_features=1024, out_features=512, bias=False)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                   (act): NewGELUActivation()
#                 )
#                 (layer_norm): T5LayerNorm()
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#           )
#         )
#         (final_layer_norm): T5LayerNorm()
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (decoder): T5Stack(
#         (embed_tokens): Embedding(32128, 512)
#         (block): ModuleList(
#           (0): T5Block(
#             (layer): ModuleList(
#               (0): T5LayerSelfAttention(
#                 (SelfAttention): T5Attention(
#                   (q): lora.Linear(
#                     (base_layer): Linear(in_features=512, out_features=384, bias=False)
#                     (lora_dropout): ModuleDict(
#                       (default): Dropout(p=0.1, inplace=False)
#                     )
#                     (lora_A): ModuleDict(
#                       (default): Linear(in_features=512, out_features=16, bias=False)
#                     )
#                     (lora_B): ModuleDict(
#                       (default): Linear(in_features=16, out_features=384, bias=False)
#                     )
#                     (lora_embedding_A): ParameterDict()
#                     (lora_embedding_B): ParameterDict()
#                     (lora_magnitude_vector): ModuleDict()
#                   )
#                   (k): lora.Linear(
#                     (base_layer): Linear(in_features=512, out_features=384, bias=False)
#                     (lora_dropout): ModuleDict(
#                       (default): Dropout(p=0.1, inplace=False)
#                     )
#                     (lora_A): ModuleDict(
#                       (default): Linear(in_features=512, out_features=16, bias=False)
#                     )
#                     (lora_B): ModuleDict(
#                       (default): Linear(in_features=16, out_features=384, bias=False)
#                     )
#                     (lora_embedding_A): ParameterDict()
#                     (lora_embedding_B): ParameterDict()
#                     (lora_magnitude_vector): ModuleDict()
#                   )
#                   (v): lora.Linear(
#                     (base_layer): Linear(in_features=512, out_features=384, bias=False)
#                     (lora_dropout): ModuleDict(
#                       (default): Dropout(p=0.1, inplace=False)
#                     )
#                     (lora_A): ModuleDict(
#                       (default): Linear(in_features=512, out_features=16, bias=False)
#                     )
#                     (lora_B): ModuleDict(
#                       (default): Linear(in_features=16, out_features=384, bias=False)
#                     )
#                     (lora_embedding_A): ParameterDict()
#                     (lora_embedding_B): ParameterDict()
#                     (lora_magnitude_vector): ModuleDict()
#                   )
#                   (o): lora.Linear(
#                     (base_layer): Linear(in_features=384, out_features=512, bias=False)
#                     (lora_dropout): ModuleDict(
#                       (default): Dropout(p=0.1, inplace=False)
#                     )
#                     (lora_A): ModuleDict(
#                       (default): Linear(in_features=384, out_features=16, bias=False)
#                     )
#                     (lora_B): ModuleDict(
#                       (default): Linear(in_features=16, out_features=512, bias=False)
#                     )
#                     (lora_embedding_A): ParameterDict()
#                     (lora_embedding_B): ParameterDict()
#                     (lora_magnitude_vector): ModuleDict()
#                   )
#                   (relative_attention_bias): Embedding(32, 6)
#                 )
#                 (layer_norm): T5LayerNorm()
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (1): T5LayerCrossAttention(
#                 (EncDecAttention): T5Attention(
#                   (q): lora.Linear(
#                     (base_layer): Linear(in_features=512, out_features=384, bias=False)
#                     (lora_dropout): ModuleDict(
#                       (default): Dropout(p=0.1, inplace=False)
#                     )
#                     (lora_A): ModuleDict(
#                       (default): Linear(in_features=512, out_features=16, bias=False)
#                     )
#                     (lora_B): ModuleDict(
#                       (default): Linear(in_features=16, out_features=384, bias=False)
#                     )
#                     (lora_embedding_A): ParameterDict()
#                     (lora_embedding_B): ParameterDict()
#                     (lora_magnitude_vector): ModuleDict()
#                   )
#                   (k): lora.Linear(
#                     (base_layer): Linear(in_features=512, out_features=384, bias=False)
#                     (lora_dropout): ModuleDict(
#                       (default): Dropout(p=0.1, inplace=False)
#                     )
#                     (lora_A): ModuleDict(
#                       (default): Linear(in_features=512, out_features=16, bias=False)
#                     )
#                     (lora_B): ModuleDict(
#                       (default): Linear(in_features=16, out_features=384, bias=False)
#                     )
#                     (lora_embedding_A): ParameterDict()
#                     (lora_embedding_B): ParameterDict()
#                     (lora_magnitude_vector): ModuleDict()
#                   )
#                   (v): lora.Linear(
#                     (base_layer): Linear(in_features=512, out_features=384, bias=False)
#                     (lora_dropout): ModuleDict(
#                       (default): Dropout(p=0.1, inplace=False)
#                     )
#                     (lora_A): ModuleDict(
#                       (default): Linear(in_features=512, out_features=16, bias=False)
#                     )
#                     (lora_B): ModuleDict(
#                       (default): Linear(in_features=16, out_features=384, bias=False)
#                     )
#                     (lora_embedding_A): ParameterDict()
#                     (lora_embedding_B): ParameterDict()
#                     (lora_magnitude_vector): ModuleDict()
#                   )
#                   (o): lora.Linear(
#                     (base_layer): Linear(in_features=384, out_features=512, bias=False)
#                     (lora_dropout): ModuleDict(
#                       (default): Dropout(p=0.1, inplace=False)
#                     )
#                     (lora_A): ModuleDict(
#                       (default): Linear(in_features=384, out_features=16, bias=False)
#                     )
#                     (lora_B): ModuleDict(
#                       (default): Linear(in_features=16, out_features=512, bias=False)
#                     )
#                     (lora_embedding_A): ParameterDict()
#                     (lora_embedding_B): ParameterDict()
#                     (lora_magnitude_vector): ModuleDict()
#                   )
#                 )
#                 (layer_norm): T5LayerNorm()
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (2): T5LayerFF(
#                 (DenseReluDense): T5DenseGatedActDense(
#                   (wi_0): Linear(in_features=512, out_features=1024, bias=False)
#                   (wi_1): Linear(in_features=512, out_features=1024, bias=False)
#                   (wo): Linear(in_features=1024, out_features=512, bias=False)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                   (act): NewGELUActivation()
#                 )
#                 (layer_norm): T5LayerNorm()
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#           )
#           (1-7): 7 x T5Block(
#             (layer): ModuleList(
#               (0): T5LayerSelfAttention(
#                 (SelfAttention): T5Attention(
#                   (q): lora.Linear(
#                     (base_layer): Linear(in_features=512, out_features=384, bias=False)
#                     (lora_dropout): ModuleDict(
#                       (default): Dropout(p=0.1, inplace=False)
#                     )
#                     (lora_A): ModuleDict(
#                       (default): Linear(in_features=512, out_features=16, bias=False)
#                     )
#                     (lora_B): ModuleDict(
#                       (default): Linear(in_features=16, out_features=384, bias=False)
#                     )
#                     (lora_embedding_A): ParameterDict()
#                     (lora_embedding_B): ParameterDict()
#                     (lora_magnitude_vector): ModuleDict()
#                   )
#                   (k): lora.Linear(
#                     (base_layer): Linear(in_features=512, out_features=384, bias=False)
#                     (lora_dropout): ModuleDict(
#                       (default): Dropout(p=0.1, inplace=False)
#                     )
#                     (lora_A): ModuleDict(
#                       (default): Linear(in_features=512, out_features=16, bias=False)
#                     )
#                     (lora_B): ModuleDict(
#                       (default): Linear(in_features=16, out_features=384, bias=False)
#                     )
#                     (lora_embedding_A): ParameterDict()
#                     (lora_embedding_B): ParameterDict()
#                     (lora_magnitude_vector): ModuleDict()
#                   )
#                   (v): lora.Linear(
#                     (base_layer): Linear(in_features=512, out_features=384, bias=False)
#                     (lora_dropout): ModuleDict(
#                       (default): Dropout(p=0.1, inplace=False)
#                     )
#                     (lora_A): ModuleDict(
#                       (default): Linear(in_features=512, out_features=16, bias=False)
#                     )
#                     (lora_B): ModuleDict(
#                       (default): Linear(in_features=16, out_features=384, bias=False)
#                     )
#                     (lora_embedding_A): ParameterDict()
#                     (lora_embedding_B): ParameterDict()
#                     (lora_magnitude_vector): ModuleDict()
#                   )
#                   (o): lora.Linear(
#                     (base_layer): Linear(in_features=384, out_features=512, bias=False)
#                     (lora_dropout): ModuleDict(
#                       (default): Dropout(p=0.1, inplace=False)
#                     )
#                     (lora_A): ModuleDict(
#                       (default): Linear(in_features=384, out_features=16, bias=False)
#                     )
#                     (lora_B): ModuleDict(
#                       (default): Linear(in_features=16, out_features=512, bias=False)
#                     )
#                     (lora_embedding_A): ParameterDict()
#                     (lora_embedding_B): ParameterDict()
#                     (lora_magnitude_vector): ModuleDict()
#                   )
#                 )
#                 (layer_norm): T5LayerNorm()
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (1): T5LayerCrossAttention(
#                 (EncDecAttention): T5Attention(
#                   (q): lora.Linear(
#                     (base_layer): Linear(in_features=512, out_features=384, bias=False)
#                     (lora_dropout): ModuleDict(
#                       (default): Dropout(p=0.1, inplace=False)
#                     )
#                     (lora_A): ModuleDict(
#                       (default): Linear(in_features=512, out_features=16, bias=False)
#                     )
#                     (lora_B): ModuleDict(
#                       (default): Linear(in_features=16, out_features=384, bias=False)
#                     )
#                     (lora_embedding_A): ParameterDict()
#                     (lora_embedding_B): ParameterDict()
#                     (lora_magnitude_vector): ModuleDict()
#                   )
#                   (k): lora.Linear(
#                     (base_layer): Linear(in_features=512, out_features=384, bias=False)
#                     (lora_dropout): ModuleDict(
#                       (default): Dropout(p=0.1, inplace=False)
#                     )
#                     (lora_A): ModuleDict(
#                       (default): Linear(in_features=512, out_features=16, bias=False)
#                     )
#                     (lora_B): ModuleDict(
#                       (default): Linear(in_features=16, out_features=384, bias=False)
#                     )
#                     (lora_embedding_A): ParameterDict()
#                     (lora_embedding_B): ParameterDict()
#                     (lora_magnitude_vector): ModuleDict()
#                   )
#                   (v): lora.Linear(
#                     (base_layer): Linear(in_features=512, out_features=384, bias=False)
#                     (lora_dropout): ModuleDict(
#                       (default): Dropout(p=0.1, inplace=False)
#                     )
#                     (lora_A): ModuleDict(
#                       (default): Linear(in_features=512, out_features=16, bias=False)
#                     )
#                     (lora_B): ModuleDict(
#                       (default): Linear(in_features=16, out_features=384, bias=False)
#                     )
#                     (lora_embedding_A): ParameterDict()
#                     (lora_embedding_B): ParameterDict()
#                     (lora_magnitude_vector): ModuleDict()
#                   )
#                   (o): lora.Linear(
#                     (base_layer): Linear(in_features=384, out_features=512, bias=False)
#                     (lora_dropout): ModuleDict(
#                       (default): Dropout(p=0.1, inplace=False)
#                     )
#                     (lora_A): ModuleDict(
#                       (default): Linear(in_features=384, out_features=16, bias=False)
#                     )
#                     (lora_B): ModuleDict(
#                       (default): Linear(in_features=16, out_features=512, bias=False)
#                     )
#                     (lora_embedding_A): ParameterDict()
#                     (lora_embedding_B): ParameterDict()
#                     (lora_magnitude_vector): ModuleDict()
#                   )
#                 )
#                 (layer_norm): T5LayerNorm()
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (2): T5LayerFF(
#                 (DenseReluDense): T5DenseGatedActDense(
#                   (wi_0): Linear(in_features=512, out_features=1024, bias=False)
#                   (wi_1): Linear(in_features=512, out_features=1024, bias=False)
#                   (wo): Linear(in_features=1024, out_features=512, bias=False)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                   (act): NewGELUActivation()
#                 )
#                 (layer_norm): T5LayerNorm()
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#           )
#         )
#         (final_layer_norm): T5LayerNorm()
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (lm_head): Linear(in_features=512, out_features=32128, bias=False)
#     )
#   )
# )

# %%
# Batch embedding function
def get_t5_embeddings(texts, model, tokenizer, batch_size=16, device="cuda" if torch.cuda.is_available() else "cpu"):
    all_embeddings = []
    model = model.to(device)
    model.eval()

    for i in tqdm(range(0, len(texts), batch_size)):
        batch = texts[i:i+batch_size]
        inputs = tokenizer(batch, return_tensors="pt", padding=True, truncation=True).to(device)

        with torch.no_grad():
            encoder_outputs = model.base_model.encoder(**inputs)
            # Mean pool across tokens
            batch_embeddings = encoder_outputs.last_hidden_state.mean(dim=1)
            all_embeddings.append(batch_embeddings.cpu().numpy())

    return np.vstack(all_embeddings)

# %%
texts = df['ingredients'].astype(str).tolist()

# Generate and save
recipe_embeddings = get_t5_embeddings(texts, model, tokenizer, batch_size=16)
np.save("/content/drive/MyDrive/recipe_model/final_model/recipe_embeddings", recipe_embeddings)

print("Saved recipe embeddings:", recipe_embeddings.shape)
print("Saved recipe embeddings to:", model_dir)
# Out:
# 100%|██████████| 5000/5000 [03:54<00:00, 21.31it/s]
# Saved recipe embeddings: (80000, 512)
# Saved recipe embeddings to: /content/drive/MyDrive/recipe_model/final_model

# %%
# Load embeddings (without training the code chunk directly above this chunk)
recipe_embeddings = np.load("/content/drive/MyDrive/recipe_model/final_model/recipe_embeddings.npy")

# %%
# Retrieval function
def recommend_recipes(query, model, tokenizer, recipe_embeddings, recipe_texts, top_k=5):
    query_emb = get_t5_embeddings(query, model, tokenizer)
    sims = cosine_similarity(query_emb, recipe_embeddings)[0]
    top_idx = np.argsort(sims)[::-1][:top_k]
    results = [(recipe_texts[i], sims[i]) for i in top_idx]
    return results

texts = df['ingredients'].astype(str).tolist()

query = "chicken, rice, soy sauce"
recommendations = recommend_recipes(query, model, tokenizer, recipe_embeddings, texts)

for recipe, score in recommendations:
    print(f"{score:.3f} – {recipe}")
# Out:
# 100%|██████████| 2/2 [00:00<00:00, 16.28it/s]
# 0.550 – ['chicken bouillon granules', 'butter', 'long-grain white rice', 'butter', 'frozen peas', 'parmesan cheese', 'salt', 'pepper', 'bacon']
# 0.548 – ['chicken broth', 'potatoes', 'carrot', 'celery', 'diced onion', 'salt', 'pepper', 'cooked chicken', 'processed cheese']
# 0.546 – ['boneless skinless chicken breasts', 'cherry tomatoes', 'fresh spinach', 'mozzarella cheese', 'feta cheese', 'bacon', 'parmesan cheese', 'oil', 'butter']
# 0.543 – ['chicken stock', 'campbell%27s cheddar cheese soup', 'refrigerated taco sauce with seasoned shredded chicken', 'salsa', 'corn', 'chili powder', 'cheddar cheese', 'flour tortilla', 'sour cream']
# 0.543 – ['carrots', 'celery ribs', 'chicken breasts', 'water', 'chicken broth', 'barley', 'fresh parsley', 'dried thyme']

# %%
# Retrieve top 5 similar recipes to the query ingredients
top_recipes = recommend_recipes(query, model, tokenizer, recipe_embeddings, df['ingredients'].tolist(), top_k=5)

# Build a prompt from retrieved recipes
query_emb = get_t5_embeddings(query, model, tokenizer)
sims = cosine_similarity(query_emb, recipe_embeddings)[0]
top_idx = np.argsort(sims)[::-1][:5] # numeric indices

context = "\n\n".join(
    " ".join(df['steps'].iloc[idx]) if isinstance(df['steps'].iloc[idx], list)
    else str(df['steps'].iloc[idx])
    for idx in top_idx
)

prompt = f"""
Available ingredients: {query}.

Reference recipes:
{context}
"""
# Out:
# 100%|██████████| 2/2 [00:00<00:00, 45.39it/s]
# 100%|██████████| 2/2 [00:00<00:00, 49.36it/s]

# %%
print(prompt)
# Out:
# Available ingredients: chicken, rice, soy sauce.
#
# Reference recipes:
# in a saucepan add bouillon crystals and 1 tbs butter to 2 cups water and bring to a boil. lower heat to low, stir in rice and simmer, covered, about 20 minutes. add 2 tbs butter, peas, salt and pepper; if necessary, add a little more water. increase heat to medium and cook about 10 minutes until peas and rice are cooked and water is absorbed. add bacon, mix light and cook another minute or so just to heat through.
#
# cook the veggies in the chicken broth until tender. add the chicken until hot. slice in the cheese and stir until melted.
#
# preheat oven to 350 degrees (if in convection 325 works as well). pound chicken breast out while making bacon (microwave the bacon it makes it crispy). lay the pounded out chicken breast smooth skin side down and spinach, tomatoes and mozzarella cheese inside, roll up and pin closed with tooth picks. heat up a pan with some veg oil and a lil' butter in it, your going to brown the sides of the chicken. lay the chicken down in the pan pinned close side down first, once its browned flip over and put parm cheese on it and then flip it over and brown the parm cheese. put the browned chicken on a baking sheet (i use a silicon pad to keep it from sticking, i suggest getting one or more of these, they're great! my mother in law gave me mine.). bake for about 20 min, or until the chicken is cooked all the way through.
#
# add cheese soup to a large stock pot. slowly stir in chicken stock. (you can do this fast or slow. i said slow for initial appearance, otherwise the cheese soup looks really lumpy. i promise it will all mix together nicely after it simmers.). add chicken, salsa, corn, chili powder, and 1 1/2 cups cheddar. simmer for 30 minutes, stirring occassionaly. serve in bowl and top with shredded cheese, tortilla strips* and sour cream*.
#
# place carrots, celery and onion in slow cooker. place chicken on top of vegetables, then add remaining ingredients except parsley and thyme. cover and cook on low 8-9 hours. remove chicken from cooker, place on cutting board. remove meat from bones and chop into 1/2 to 1 inch pieces, discard bones. stir chicken, parsley, and thyme into stew. increase heat setting and cook for another 15-20 minutes.

# %% [markdown]
# # 6. Model evaluation (Retriever)

# %% [markdown]
# ## 6.1 Stratified sampling

# %%
# Get original dataframe indices for test set
test_df_indices = test_df.index.tolist()

# Sample from test set for faster evaluation
np.random.seed(42)
SAMPLE_SIZE = 500
sample_size = min(SAMPLE_SIZE, len(test_dataset))

# Create test queries using existing test set
test_queries = []
for i in range(sample_size):
    original_idx = test_df_indices[i] # map to original df index

    test_queries.append({
        'test_dataset_idx': i, # index in test_dataset
        'original_df_idx': original_idx, # index in original df
        'query_ingredients': test_dataset[i]['input_text'],
        'true_recipe': test_dataset[i]['target_text'],
    })

# %% [markdown]
# ## 6.2 Key metrics

# %%
# Top-1 similarity
top1_similarities = []
retrieval_times = []
all_retrievals = []

for test_item in tqdm(test_queries, desc="Testing retrieval"):
    query = test_item['query_ingredients']
    query_idx = test_item['original_df_idx'] # use original df index

    # Time the retrieval
    start_time = time.time()

    # Get query embedding and similarities
    query_emb = get_t5_embeddings([query], model, tokenizer)
    sims = cosine_similarity(query_emb, recipe_embeddings)[0]

    # Get top-5 (excluding query itself)
    all_indices = np.argsort(sims)[::-1]
    top_idx = [i for i in all_indices if i != query_idx][:5]

    retrieval_time = time.time() - start_time

    # Store metrics
    top1_similarities.append(sims[top_idx[0]])
    retrieval_times.append(retrieval_time)

    # Store for later use
    all_retrievals.append({
        'query': query,
        'query_idx': query_idx,
        'top1_idx': top_idx[0],
        'top1_similarity': sims[top_idx[0]],
        'top5_indices': top_idx,
        'top5_similarities': [sims[i] for i in top_idx],
        'true_recipe': test_item['true_recipe']
    })

# Results
avg_top1_sim = np.mean(top1_similarities)

print(f"Average Top-1 Similarity:{avg_top1_sim:.4f}")
# Out:
# Testing retrieval:   0%|          | 0/500 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:00<00:00, 63.53it/s]
# Testing retrieval:   0%|          | 1/500 [00:00<01:39,  5.03it/s]
# 100%|██████████| 1/1 [00:00<00:00, 50.38it/s]
# Testing retrieval:   0%|          | 2/500 [00:00<01:48,  4.60it/s]
# 100%|██████████| 1/1 [00:00<00:00, 45.51it/s]
# Testing retrieval:   1%|          | 3/500 [00:00<01:54,  4.35it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.67it/s]
# Testing retrieval:   1%|          | 4/500 [00:00<01:57,  4.23it/s]
# 100%|██████████| 1/1 [00:00<00:00, 51.71it/s]
# Testing retrieval:   1%|          | 5/500 [00:01<01:53,  4.38it/s]
# 100%|██████████| 1/1 [00:00<00:00, 52.70it/s]
# Testing retrieval:   1%|          | 6/500 [00:01<01:51,  4.44it/s]
# 100%|██████████| 1/1 [00:00<00:00, 55.16it/s]
# Testing retrieval:   1%|▏         | 7/500 [00:01<01:51,  4.42it/s]
# 100%|██████████| 1/1 [00:00<00:00, 42.91it/s]
# Testing retrieval:   2%|▏         | 8/500 [00:01<01:52,  4.38it/s]
# 100%|██████████| 1/1 [00:00<00:00, 45.19it/s]
# Testing retrieval:   2%|▏         | 9/500 [00:02<01:56,  4.22it/s]
# 100%|██████████| 1/1 [00:00<00:00, 38.35it/s]
# Testing retrieval:   2%|▏         | 10/500 [00:02<02:03,  3.96it/s]
# 100%|██████████| 1/1 [00:00<00:00, 44.21it/s]
# Testing retrieval:   2%|▏         | 11/500 [00:02<02:10,  3.75it/s]
# 100%|██████████| 1/1 [00:00<00:00, 41.03it/s]
# Testing retrieval:   2%|▏         | 12/500 [00:02<02:10,  3.73it/s]
# 100%|██████████| 1/1 [00:00<00:00, 23.54it/s]
# Testing retrieval:   3%|▎         | 13/500 [00:03<02:15,  3.60it/s]
# 100%|██████████| 1/1 [00:00<00:00, 26.54it/s]
# Testing retrieval:   3%|▎         | 14/500 [00:03<02:21,  3.44it/s]
# 100%|██████████| 1/1 [00:00<00:00, 25.27it/s]
# Testing retrieval:   3%|▎         | 15/500 [00:03<02:26,  3.31it/s]
# 100%|██████████| 1/1 [00:00<00:00, 23.24it/s]
# Testing retrieval:   3%|▎         | 16/500 [00:04<02:27,  3.27it/s]
# 100%|██████████| 1/1 [00:00<00:00, 26.58it/s]
# Testing retrieval:   3%|▎         | 17/500 [00:04<02:26,  3.29it/s]
# 100%|██████████| 1/1 [00:00<00:00, 29.48it/s]
# Testing retrieval:   4%|▎         | 18/500 [00:04<02:27,  3.28it/s]
# 100%|██████████| 1/1 [00:00<00:00, 27.73it/s]
# Testing retrieval:   4%|▍         | 19/500 [00:05<02:26,  3.28it/s]
# 100%|██████████| 1/1 [00:00<00:00, 22.20it/s]
# Testing retrieval:   4%|▍         | 20/500 [00:05<02:26,  3.27it/s]
# 100%|██████████| 1/1 [00:00<00:00, 35.79it/s]
# Testing retrieval:   4%|▍         | 21/500 [00:05<02:23,  3.35it/s]
# 100%|██████████| 1/1 [00:00<00:00, 39.58it/s]
# Testing retrieval:   4%|▍         | 22/500 [00:05<02:21,  3.37it/s]
# 100%|██████████| 1/1 [00:00<00:00, 41.11it/s]
# Testing retrieval:   5%|▍         | 23/500 [00:06<02:21,  3.36it/s]
# 100%|██████████| 1/1 [00:00<00:00, 19.35it/s]
# Testing retrieval:   5%|▍         | 24/500 [00:06<02:19,  3.41it/s]
# 100%|██████████| 1/1 [00:00<00:00, 47.24it/s]
# Testing retrieval:   5%|▌         | 25/500 [00:06<02:08,  3.69it/s]
# 100%|██████████| 1/1 [00:00<00:00, 52
15it/s]
# 100%|██████████| 1/1 [00:00<00:00, 30.50it/s]
# Testing retrieval: 100%|██████████| 500/500 [02:07<00:00,  3.93it/s]
# Average Top-1 Similarity:0.8005

# %%
# Precision@5
precision_scores = []

# Define "relevant" as similarity > 0.7
RELEVANCE_THRESHOLD = 0.7

for retrieval in tqdm(all_retrievals, desc="Calculating precision"):
    print(retrieval)
    top5_sims = retrieval['top5_similarities']

    # Count how many of top-5 are relevant
    relevant_count = sum(1 for sim in top5_sims if sim >= RELEVANCE_THRESHOLD)

    precision = relevant_count / 5
    precision_scores.append(precision)

avg_precision = np.mean(precision_scores)
std_precision = np.std(precision_scores)

print(f"Average Precision@5:  {avg_precision:.2%}")
# Out:
# Calculating precision: 100%|██████████| 500/500 [00:00<00:00, 38450.93it/s]
# {'query': 'rice cakes, tomatoes, hot sauce, parmesan cheese, salt and pepper', 'query_idx': 47044, 'top1_idx': np.int64(27091), 'top1_similarity': np.float32(0.75112635), 'top5_indices': [np.int64(27091), np.int64(39596), np.int64(14800), np.int64(23797), np.int64(18004)], 'top5_similarities': [np.float32(0.75112635), np.float32(0.7504564), np.float32(0.74480367), np.float32(0.7420081), np.float32(0.7408287)], 'true_recipe': 'quick &amp; easy low cal breakfast or lunch\n\ningredients:\n2 rice cakes (you know those things that look like styrofoam)\n4 slices tomatoes\nhot sauce\n2 teaspoons parmesan cheese, grated\nsalt and pepper\n\nsteps:\nplace tomato slices on the rice cakes.\nsprinkle with hot sauce (as much or as little as you want), salt and pepper.\ndrizzle with parmesan.\nbroil for about 3-4 minutes.'}
# {'query': 'butter, onion, carrot, plain flour, tomatoes, water, bay leaf, sugar, ground mace, salt and pepper, arrowroot, cream', 'query_idx': 44295, 'top1_idx': np.int64(19659), 'top1_similarity': np.float32(0.7989136), 'top5_indices': [np.int64(19659), np.int64(19300), np.int64(53609), np.int64(46578), np.int64(55774)], 'top5_similarities': [np.float32(0.7989136), np.float32(0.79873115), np.float32(0.7954407), np.float32(0.7948744), np.float32(0.7933)], 'true_recipe': 'spicy tomato soup\n\ningredients:\n1 ounce butter\n1 medium onion\n1 carrot\n1 tablespoon plain flour\n1 lb ripe tomatoes\n1 pint water or 1 pint vegetable stock\n1 bay leaf\n2 teaspoons sugar\n1 pinch ground mace or 1 pinch nutmeg\nsalt and pepper\n1 teaspoon arrowroot\n3 -4 tablespoons cream\n\nsteps:\nslice tomatoes, onion and carrot.\nmelt butter in a medium size saucepan.\nadd the onion and carrot, cover, and allow to soften for 5-6 minutes.\nremove from the heat, stir in the plain flour, add tomatoes, stock or water, bay leaf, sugar, mace or nutmeg and seasoning.\nstir until boiling, simmer for 20-30 minutes.\nrub soup through sieve, pour back into rinsed saucepan, and reheat.\nadjust seasoning, and thicken slightly if necessary with a teaspoon or more of arrowroot blended with a tablespoon of cold water.\nreboil to cook the arrowroot if used to thicken the soup.\nadd cream if used.\nif cream is added do not boil the soup.\nif required, a teaspoon of tomato paste may be added to the tomato soup for extra colour and flavour.\nserve with crusty bread, the kind that you have to break apart with your hands.\nfeel free to dip your chunks of bread into the soup.'}
# {'query': 'all-purpose flour, salt, shortening, cold water, almonds, sugar, cornstarch, milk, egg yolks, margarine, vanilla, bananas, lemon juice, strawberries, whipping cream, sugar, almond extract', 'query_idx': 74783, 'top1_idx': np.int64(33962), 'top1_similarity': np.float32(0.80156434), 'top5_indices': [np.int64(33962), np.int64(70512), np.int64(23797), np.int64(73721), np.int64(78153)], 'top5_similarities': [np.float32(0.80156434), np.float32(0.79741275), np.float32(0.7970502), np.float32(0.79549026), np.float32(0.79485834)], 'true_recipe': 'strawberry  banana cream pie\n\ningredients:\n1 1/4 cups all-purpose flour\n1/4 teaspoon salt\n1/3 cup shortening or 1/3 cup lard\n4 -5 tablespoons cold water\n1/4 cup finely chopped almonds, toasted\n1/2 cup sugar\n2 tablespoons cornstarch\n1 3/4 cups milk\n2 beaten egg yolks\n1 tablespoon margarine or 1 tablespoon butter\n1/2 teaspoon vanilla\n2 medium bananas\n2 teaspoons lemon juice\n2 cups sliced strawberries\n1/2 cup whipping cream\n1 tablespoon sugar\n1/4 teaspoon almond extract\n\nsteps:\nin a bowl stir together 1-1/4 cups all-purpose flour and 1/4 teaspoon salt. using a pastry blender, cut in 1/3 cup shortening until pieces are pea-size. using 4 to 5 tablespoons cold water total, sprinkle 1 tablespoon of water at a time over the flour mixture, tossing with a fork until all of the dough is moistened. form dough into a ball.\non a lightly floured surface, roll out dough to a 12-inch circle. transfer pastry to a 9-inch pie plate. ease pastry into pie plate, being careful not to stretch pastry.\ntrim pastry to 1/2 inch beyond edge of plate. fold under extra pastry. crimp edge of pastry. do not prick pastry. line the pastry shell with a double thickness of foil. bake in a 450 degree f. oven 8 minutes. remove foil. bake 4 to 5 minutes more or until set and dry. cool.\nfor filling, in a saucepan mix the 1/2 cup sugar and cornstarch. gradually stir in milk. cook and stir until bubbly. cook and stir 2 minutes more. remove from heat. stir about 1 cup of the hot mixture into the beaten egg yolks. return all to saucepan. bring to a gentle boil. cook and stir 2 minutes more. remove from heat. stir in margarine and vanilla. cover surface with plastic wrap.\nslice bananas 1/4-inch-thick; toss with lemon juice. (you should have about 1-1/4 cups). spread half the hot filling evenly into pastry shell. arrange half the bananas and strawberries on top. top with remaining filling, bananas, and strawberries. cover; chill 1 to 6 hours.\nbefore serving, beat the whipping cream, 1 tablespoon sugar, and almond extract until stiff peaks form. pipe or dollop onto pie. makes 8 servings.'}
# {'query': 'peanut oil, extra firm tofu, onion, soy sauce, tomatoes, red peppers, jalapenos, eggplant, mushrooms, summer squash, scallion, tomato paste, fresh cilantro', 'query_idx': 70975, 'top1_idx': np.int64(39596), 'top1_similarity': np.float32(0.8331553), 'top5_indices': [np.int64(39596), np.int64(14348), np.int64(61635), np.int64(15283), np.int64(20515)], 'top5_similarities': [np.float32(0.8331553), np.float32(0.8315363), np.float32(0.8265865), np.float32(0.82542634), np.float32(0.8242816)], 'true_recipe': 'tofu with eggplant (aubergine)  and peppers\n\ningredients:\n3 tablespoons peanut oil\n1 1/2 lbs extra firm tofu, drained and cut into 1-inch cubes\n1 onion, chopped\n3 tablespoons soy sauce\n3 large tomatoes, peeled and cut into eighths\n3 large red peppers, chopped\n1 small jalapenos or 1 small other hot pepper, seeded and minced\n1 large eggplant, cut into 1-inch cubes\n1 1/2 lbs mushrooms\n2 summer squash, cut into 1-inch cubes\n1 bunch scallion, coarsely chopped (white and green parts)\n1 1/2 tablespoons tomato paste\n6 sprigs fresh cilantro, for garnish\n\nsteps:\nplace tofu cubes into a steamer and allow to steam for 20 to 30 minutes while chopping vegetables.\nmeanwhile, heat oil in a wok or large skillet until very hot. transfer tofu to pan and sauté until brown on all sides, then remove from pan and set aside.\nin same pan, sauté onion for one minute. add soy sauce and one tablespoon water if necessary. add tomatoes, red peppers, hot peppers, eggplant, mushrooms, squash, scallions, and tomato paste and reduce heat. simmer for about 10 minutes, or until vegetables are soft. add tofu and continue cooking until tofu is heated through.\nserve on platter, garnished with cilantro and rice or noodles. we recommend forbidden rice, though not exactly traditional, for its exotic nutty flavor and psychedelic color that beautifully compliments the eggplant and peppers.'}
# {'query': 'cube steaks, worcestershire sauce, flour, salt, pepper, garlic powder, vegetable oil, onion, water', 'query_idx': 46645, 'top1_idx': np.int64(18392), 'top1_similarity': np.float32(0.80628693), 'top5_indices': [np.int64(18392), np.int64(5742), np.int64(23797), np.int64(33043), np.int64(28138)], 'top5_similarities': [np.float32(0.80628693), np.float32(0.7924439), np.float32(0.7879373), np.float32(0.7862868), np.float32(0.7837731)], 'true_recipe': 'saucy cube steak\n\ningredients:\n2 lbs cube steaks, cut into serving size pieces\n1/4 cup worcestershire sauce\n1/4 cup flour\n1/2 teaspoon salt\n1/2 teaspoon pepper\n1/2 teaspoon garlic powder\n3 tablespoons vegetable oil\n1/2 cup minced onion\n2 cups water\n\nsteps:\ncover the steak with worcestershire sauce; let sit for 5 minutes.\nmix the flour with salt, pepper, and garlic powder.\nheat oil in 12 inch skillet.\nremove steaks from worcestershire sauce; dip in flour mixture.\nbrown steaks on both sides for 6 minutes.\nadd onions; cook 2 minutes.\nadd water; bring to a boil.\nreduce heat; cover and simmer for 10 minutes.'}
# {'query': 'brown sugar, shortening, molasses, flour, baking soda, salt, cinnamon, nutmeg, allspice, ginger, clove, apples, raisins, dates, currants, candied peel, raisins, soft breadcrumbs, sherry wine', 'query_idx': 8215, 'top1_idx': np.int64(3975), 'top1_similarity': np.float32(0.86343324), 'top5_indices': [np.int64(3975), np.int64(79544), np.int64(11498), np.int64(30285), np.int64(25078)], 'top5_similarities': [np.float32(0.86343324), np.float32(0.8610729), np.float32(0.8608008), np.float32(0.86038065), np.float32(0.8603095)], 'true_recipe': 'last minute christmas pudding\n\ningredients:\n3/4 cup brown sugar\n1/2 cup shortening\n2 tablespoons molasses\n1/3 cup flour\n1 teaspoon baking soda\n1 teaspoon salt\n1 teaspoon cinnamon\n1/2 teaspoon nutmeg\n1/2 teaspoon allspice\n1/2 teaspoon ginger\n1/4 teaspoon clove\n3 cups apples, peeled, chopped and firmly packed\n1 cup raisins, seedless\n1 cup dates, choped\n1/2 cup currants\n1/2 cup candied peel, chopped\n1/2 cup raisins, seeded\n2 cups soft breadcrumbs\n1/4 cup sherry wine\n\nsteps:\npour sherry over fruit; set aside.\ncream shortening, sugar and molasses together.\nadd dry ingredients.\nadd fruit and breadcrumbs.\nspoon into greased pudding mold or molds. cover with greased brown paper.\nsteam 2 hours for small molds; 3 hours for large.\nthis pudding can be made ahead and stored, but is equally good made the day it is served. resteam before serving or microwave. serve with hard sauce or brown sugar sauce.'}
# {'query': 'unsweetened coconut, evaporated milk, sugar, butter, lemon rind', 'query_idx': 65509, 'top1_idx': np.int64(22894), 'top1_similarity': np.float32(0.7664774), 'top5_indices': [np.int64(22894), np.int64(22766), np.int64(38503), np.int64(14406), np.int64(35079)], 'top5_similarities': [np.float32(0.7664774), np.float32(0.75847244), np.float32(0.755495), np.float32(0.75374115), np.float32(0.7534317)], 'true_recipe': 'zucre coco -- moroccan coconut fudge cakes\n\ningredients:\n2 cups moist grated unsweetened coconut\n3/4 cup evaporated milk\n2 cups sugar\n1 ounce butter\n2 tablespoons lemon rind, grated\n\nsteps:\nline an 8x8 pan or similar sized round pan with foil (as i do here as we do not have waxed paper) or waxed paper.\nin a heavy bottomed 2qt. saucepan combine coconut, evaporated milk and sugar.\nsimmer gently to soft ball stage; 238 degrees. here we test in cold water and do not use a thermometer. the cooking time is my best guess as i have never made this using a western stove.\nstir in the butter and lemon rind and allow to cool to room temperature.\nbeat until thick and glossy as you would for fudge but beating to glossy not until it loses it\'s gloss.\npour into prepared pan and chill 2 hours. cut into 1/2" to 1" squares.'}
# {'query': 'refrigerated pie crusts, semi-sweet chocolate chips, butter, sugar, ground almonds, egg, egg yolk, frozen raspberries, sugar, lemon juice, sweetened whipped cream, chocolate curls, raspberries', 'query_idx': 62715, 'top1_idx': np.int64(38750), 'top1_similarity': np.float32(0.8065682), 'top5_indices': [np.int64(38750), np.int64(3790), np.int64(7443), np.int64(74972), np.int64(6476)], 'top5_similarities': [np.float32(0.8065682), np.float32(0.8059584), np.float32(0.8033017), np.float32(0.8024794), np.float32(0.802317)], 'true_recipe': 'fudge crostata with raspberry sauce\n\ningredients:\n1 (15 ounce) package refrigerated pie crusts\n\n1 (6 ounce) package semi-sweet chocolate chips\n1/2 cup butter, softened\n2/3 cup sugar\n1 cup ground almonds\n1 egg\n1 egg yolk\n\n1 (12 ounce) package frozen raspberries, without syrup, thawed\n3/4 cup sugar\n1 teaspoon lemon juice\n\nsweetened whipped cream\nchocolate curls\n1 whole raspberries\n\nsteps:\nprepare pie crust according to pkg. directions for two-crust pie using 10 inch tart pan with removable bottom or 9 inch pie pan.\nplace 1 prepared crust in pan; press in bottom and up sides of pan. trim edges if necessary.\nplace cookie sheet in oven to preheat. heat oven to 375.\nin small saucepan, melt chocolate chips and 2 t. of the butter over low heat, stirring constantly until smooth. in medium bowl, combine remaining 6 t. of butter and 2/3 cups of sugar; beat until light and fluffy. add almonds, egg, egg yolk and melted chocolate; blend well. spread mixture evenly in bottom of crust-lined pan.\nto make lattice top, cut 2nd crust into 1/2 inch wide strips. arrange strips in lattice design over chocolate mixture. trime and seal edges.\nplace tart on preheated cookie sheet. bake at 375 for 45-50 minutes or until crust is golden brown. if necessary, cover edge of crust with strips of foil during last 10-15 minutes of baking to prevent excessive browning. cool completely.\nmeanwhile, in blend container or food processor with metal blend, blend raspberries at high speed until smooth. place strainer over small saucepan; pour berries into strainer. press berries with back of spoon through strainer to remove seeds; discard seeds.\nadd 3/4 cup sugar and lemon juice; blend well. bring mixture to a boil, stirring constantly. reduce heat to medium-low; boil 3 minutes, stirring constantly. cool; refrigerate until serving time. garnish crostata with whipped cream, chocolate curls and whole raspberries. serve with raspberry sauce. store in refrigerator.'}
# {'query': 'marjoram leaves, thyme leaves, chives, mint, unsalted butter, all-purpose flour, water, salt, black pepper, egg yolks, sour cream, hard rolls', 'query_idx': 39859, 'top1_idx': np.int64(57836), 'top1_similarity': np.float32(0.8426163), 'top5_indices': [np.int64(57836), np.int64(9984), np.int64(33962), np.int64(73429), np.int64(30704)], 'top5_similarities': [np.float32(0.8426163), np.float32(0.83652866), np.float32(0.8330423), np.float32(0.8322237), np.float32(0.8308543)], 'true_recipe': 'fuvesleves (herb soup)\n\ningredients:\n1 teaspoon marjoram leaves\n1 teaspoon thyme leaves\n1 tablespoon chives, cut in 1 inch pieces\n1 teaspoon apple mint, chopped\n4 tablespoons unsalted butter\n1 tablespoon all-purpose flour\n6 cups water\n1 teaspoon salt\n1 pinch black pepper\n3 egg yolks\n1 tablespoon sour cream\n3 hard rolls, cut in half,toasted\n\nsteps:\ncook all the herbs in 2 tablespoons butter for 2-3 minutes.\nsprinkle with flour, then stir and cook another 4 minutes.\nset aside.\npour 6 cups of water into a pot and bring to a slow simmer.\nadd salt and pepper.\nmix egg yolks, sour cream and remaining butter; whip into the simmering soup.\ncook soup over low heat, stirring, until it thickens.\nadd herbs and simmer another few minutes.\nplace half of a toasted roll in a soup plate and ladle soup over it.'}
# {'query': 'russet potatoes, eggs, queso ranchero, garlic clove, evaporated milk, chili paste, olive oil, water crackers, lettuce leaves, black olives', 'query_idx': 58834, 'top1_idx': np.int64(39596), 'top1_similarity': np.float32(0.7914146), 'top5_indices': [np.int64(39596), np.int64(14348), np.int64(17837), np.int64(39432), np.int64(5742)], 'top5_similarities': [np.float32(0.7914146), np.float32(0.7892562), np.float32(0.78872806), np.float32(0.7880389), np.float32(0.7865838)], 'true_recipe': 'papas a la huancaina\n\ningredients:\n6 russet potatoes, peeled boiled, and sliced\n4 eggs, hard boiled\n9 ounces queso ranchero (or queso casero or feta cheese)\n1 garlic clove, crushed\n1 (12 ounce) can evaporated milk\n2 tablespoons peruvian yellow chili paste (aji amarillo paste-very spicy!)\n1 -2 tablespoon olive oil\n5 -8 water crackers\n\n3 -4 lettuce leaves\nblack olives\n\nsteps:\nfor the papas:\nassemble lettuce leaves on a nice plate or platter.\nlay potato slices on top, trying to keep the round discs intact.\nfor the salsa huancaina:\nin a blender container or food processor, place cheese, garlic, evaporated milk and aji paste, blend until smooth.\nadd 2 yolks of the hard boiled eggs, and a few water crackers.\nwhile blender is running, drizzle in 1 t of oil.\ncheck consistency.\nit should be about the consistency of thin cake batter.\nif it needs more thickening, add more crackers and oil.\ncheck seasoning, if you are using feta cheese, it might not need salt, you can also add a bit more aji if you like it spicy.\nto serve, pour sauce over potatoes and lettuce.\ngarnish with remaining 2 hard boiled eggs, cut in wedges and black olives.'}
# {'query': 'flour, baking powder, unsalted butter, egg, vanilla, sugar, heavy cream, egg, almonds, sugar', 'query_idx': 53519, 'top1_idx': np.int64(33962), 'top1_similarity': np.float32(0.7708317), 'top5_indices': [np.int64(33962), np.int64(26791), np.int64(16390), np.int64(14406), np.int64(28474)], 'top5_similarities': [np.float32(0.7708317), np.float32(0.7688937), np.float32(0.7679126), np.float32(0.7657503), np.float32(0.7624884)], 'true_recipe': "german vanillebrezeln (vanilla pretzels)\n\ningredients:\n3 1/2 cups flour\n1 teaspoon baking powder\n1 cup unsalted butter\n1 egg, lightly beaten\n1 teaspoon vanilla\n1 cup sugar\n1/2 cup heavy cream\n1 egg, lightly beaten\n1/2 cup finely chopped unblanched almonds (with skins on)\n2 -3 tablespoons sugar\n\nsteps:\nsift flour with baking powder into a wide bowl.\nform a well in flour.\nto this add butter, cut into small pieces, 1 beaten egg, vanilla, sugar and cream.\nwork ingredients together with your fingertips until you have a smooth dough that sticks together.\nform a ball, wrap in waxed paper and chill 30 minutes.\nbreak dough off in pieces slightly larger than a walnut.\nwith floured hands, roll each piece to a thin rope.\nshape into a pretzel.\narrange on buttered baking sheet and chill 20 minutes.\nbrush with beaten egg and sprinkle with chopped almonds, then sugar.\nbake in preheated 325 f.\noven for about 25 minutes, or until golden brown.\nmakes about 3 dozen cookies.\nvariation: the almond and sugar topping may be omitted and the pretzels baked and cooled, then spread with white sugar glaze.\nwhite sugar glaze: for cookies and cakes, and especially for lebkuchen, 1/3 cup confectioners' sugar, 1 1/2 tablespoons cornstarch, 1/2 teaspoon vanilla or almond extract, 1 teaspoon rum or brandy (optional), 1/2 to 1 1/4 tablespoons hot water, or as needed.\ncombine sugar, cornstarch, flavorings and rum or brandy.\ngradually stir in hot water, a tablespoonful at a time, until you have a smooth thick paste.\nspread on warm cookies.\nif mixture cools and thickens as you work, thin with additional hot water.\nsugar sprinkles can be scattered on the glaze before it hardens.\nmakes 1/4 cup, or enough to ice about fifteen 1 1/2 inch cookies.\nvisions of sugar plums."}
# {'query': 'frying chickens, lemon juice, vegetable oil, soy sauce, gingerroot, onion salt, garlic powder', 'query_idx': 833, 'top1_idx': np.int64(30204), 'top1_similarity': np.float32(0.78970623), 'top5_indices': [np.int64(30204), np.int64(9429), np.int64(23613), np.int64(12612), np.int64(27837)], 'top5_similarities': [np.float32(0.78970623), np.float32(0.7896679), np.float32(0.78923535), np.float32(0.78710943), np.float32(0.7840757)], 'true_recipe': 'marinated ginger chicken\n\ningredients:\n3 lbs frying chickens\n1/2 cup lemon juice\n1/2 cup vegetable oil\n1/4 cup soy sauce\n1 teaspoon gingerroot, grated or 1 tablespoon ginger, ground\n1 teaspoon onion salt\n1/4 teaspoon garlic powder\n\nsteps:\ncut chicken in to serving parts if not already in that form.\nplace chicken in shallow baking dish.\nin small bowl, combine remaining ingredients; pour over chicken.\ncover, refrigerate 4 hours or overnight, turning occasionally.\ngrill or broil as desired, basting frequently with marinade.\nrefrigerate leftovers'}
# {'query': 'brown flour, yeast, olive oil, sugar, salt, warm water', 'query_idx': 51037, 'top1_idx': np.int64(39590), 'top1_similarity': np.float32(0.7161536), 'top5_indices': [np.int64(39590), np.int64(28138), np.int64(16390), np.int64(32953), np.int64(20327)], 'top5_similarities': [np.float32(0.7161536), np.float32(0.7129687), np.float32(0.71063507), np.float32(0.7092086), np.float32(0.7091444)], 'true_recipe': "peasy weasy organic brown bread\n\ningredients:\n5 cups organic brown flour\n3 teaspoons dried bread yeast\n5 tablespoons olive oil\n1 tablespoon sugar (or to taste)\n1 tablespoon salt (or to taste)\nwarm water (these are all guesstimates as i never measure the ingredients, so it never comes out tasting exactl)\n\nsteps:\nmix all the dry ingredients together in a large metal pot (needs to have a fitting lid, dry ingredients need to come up to less than a third of the height of the pot).\nadd olive oil and mix.\nadd enough warm water to mix into a soft spoonable consistency- this is what is so easy about this bread: no kneading, just mix with a wooden spoon.\nif it´s too liquid, add a little more flour.\nit should stick to the spoon, but be easy enough to mix.\nput lid on pan and put in a warm place to rise.\ni put it out in the sun on a warm day, or in the oven with a candle if it´s cold outside.\nwhen the mixture has doubled in volume, spoon mixture into two oven-dishes which you´ve oiled and floured(to make non-stick).\nlet these rise again in a warm place.\nwhen they've doubled in volume again, turn oven on and place inside at medium high temperature until you can smell bread-smell!\nabout 45 minutes, but depends how high your oven is.\ntap top of bread with a knife.\nif it sounds hollow turn oven off and leave breads inside until oven has cooled down (i leave them overnight)."}
# {'query': 'butter, olive oil, beef, garlic, bacon, pickling onions, button mushrooms, tomato paste, red wine, beef stock, salt and pepper, fresh thyme', 'query_idx': 54368, 'top1_idx': np.int64(21489), 'top1_similarity': np.float32(0.8172592), 'top5_indices': [np.int64(21489), np.int64(11950), np.int64(9429), np.int64(15573), np.int64(34412)], 'top5_similarities': [np.float32(0.8172592), np.float32(0.812651), np.float32(0.81121904), np.float32(0.8110297), np.float32(0.80913264)], 'true_recipe': "my beef burgundy\n\ningredients:\n3 tablespoons butter\n3 tablespoons olive oil\n500 g gravy beef\n2 cloves garlic, chopped\n1 slice bacon, chopped roughly\n8 pickling onions, peeled and left whole\n350 g button mushrooms, whole or cut in half if they are large\n125 ml tomato paste\n250 ml red wine (whatever you prefer, i usually use a blend)\n125 ml beef stock\nsalt and pepper\n1 teaspoon fresh thyme\n\nsteps:\nfirst prepare the beef, cut any excess fat off and cut into roughly 2cm cubes.\nmelt one tablespoon of the butter and olive oil over a fairly high heat.\nsaute the meat in batches, constantly moving it around the pan.\nit should be well and truly sealed but not cooked through.\nremove and drain on paper towels.\nrepeat with remaining beef, using an additional tablespoon of butter and oil if you need it.\nadd the last tablespoons of oil and butter to the pan with the mushrooms, onions, bacon, garlic and thyme.\nstir until the onions gain a little colour.\nadd the liquids and tomato paste to the pan, scrape up all the black bits.\nnow stir in the meat.\nlightly season.\n(you may need to readjust this at the end) turn the heat down to low and simmer covered for two to three hours.\ntowards the end you may wish to remove the lid to thicken up the sauce.\n(alternatively you could use the slow cooker at this point, but you'd have two things to wash up) i serve this with bread or pasta, it really depends but i prefer fresh french bread with this."}
# {'query': 'ground beef, chili beans, whole kernel corn, diced tomatoes, rotel tomatoes, ranch dressing mix, taco seasoning mix', 'query_idx': 25540, 'top1_idx': np.int64(17837), 'top1_similarity': np.float32(0.7868657), 'top5_indices': [np.int64(17837), np.int64(18361), np.int64(3533), np.int64(14515), np.int64(12271)], 'top5_similarities': [np.float32(0.7868657), np.float32(0.78418064), np.float32(0.7827642), np.float32(0.7778576), np.float32(0.7775501)], 'true_recipe': 'taco soup\n\ningredients:\n2 lbs browned ground beef\n2 (16 ounce) cans chili beans\n2 (15 ounce) cans whole kernel corn\n2 (14 1/2 ounce) cans diced tomatoes\n1 (10 ounce) can rotel tomatoes\n1 (1 ounce) package ranch dressing mix\n1 (1 1/4 ounce) package taco seasoning mix\n\nsteps:\ncombine all ingredients in crock-pot and cook on high 4-6 hours.'}
# {'query': 'smoked pork chops, pineapple slices, brown sugar, spicy brown mustard, sweet onion, butter, unsalted butter, garlic clove, salt and pepper', 'query_idx': 36506, 'top1_idx': np.int64(18004), 'top1_similarity': np.float32(0.80467844), 'top5_indices': [np.int64(18004), np.int64(35032), np.int64(1492), np.int64(60346), np.int64(59304)], 'top5_similarities': [np.float32(0.80467844), np.float32(0.802696), np.float32(0.80048263), np.float32(0.8001083), np.float32(0.7997375)], 'true_recipe': "smoked pork chops with pineapple\n\ningredients:\n6 smoked pork chops or 6 pork chops\n6 pineapple slices, with juice\n1/3 cup brown sugar\n2 tablespoons spicy brown mustard\n1 medium sweet onion, finely chopped\n4 tablespoons butter\n2 tablespoons unsalted butter\n1 -2 large garlic clove, crushed\nsalt and pepper\n\nsteps:\npreheat oven to 350 degrees f.\nin a medium-sized skillet over low-medium heat, melt the 4 tablespoons of butter, add the sugar and stir until dissolved. add the sweet onions, stir. cook the onions until tender; stirring often, don't let them brown. add the pineapples with their juice and arrange in a single layer. reduce heat to low and allow them to caramelize, 5-7 minutes. remove from heat.\nin a large skillet add 1 1/2-2 cups of water and bring to a boil, place pork chops in the boiling water and cook until no longer pink, 5-6 minutes remove from the water.\nin a separate large skillet over medium-high heat, melt the 2 tablespoons of unsalted butter, add the garlic and cook for 1 minute, add the mustard and stir into the butter. sprinkle both sides of each chop with pepper and salt and add to the skillet with the garlic and mustard. cook on each side for 5-7 minutes. don't move them while cooking. remove from heat. allow them to rest in skillet for 2 minutes.\ntransfer pork chops to a large ungreased glass baking dish, arrange the porkchops in a single layer. put one pineapple slice on top of each chop and spoon the onions from the pan over them. bake for 15-20 mins or until done (depending on the thickness of you porkchops) enjoy!"}
# {'query': 'potatoes, onion, flour, salt, white pepper, butter, milk, shredded cheddar cheese', 'query_idx': 42403, 'top1_idx': np.int64(36560), 'top1_similarity': np.float32(0.7558646), 'top5_indices': [np.int64(36560), np.int64(38715), np.int64(73374), np.int64(6922), np.int64(30149)], 'top5_similarities': [np.float32(0.7558646), np.float32(0.7555911), np.float32(0.75480664), np.float32(0.75401294), np.float32(0.7539696)], 'true_recipe': 'lover boys  scalloped potatoes\n\ningredients:\n4 cups thinly sliced potatoes, about 6 to 8 medium potatoes\n1/2 cup chopped onion\n2 tablespoons flour\n1 teaspoon salt\n1/4 teaspoon white pepper\n1/4 cup butter\n2 cups scalded milk\n1/2 cup shredded cheddar cheese\n\nsteps:\nwith 1 tablespoons butter, butter a 2-quart baking dish, place a layer of about 1/3 of the potatoes. in a cup or small bowl, combine flour with salt and pepper. sprinkle about half of the flour mixture over the onions &amp; potatoes; repeat with another layer of potatoes and the flour mixture and top with remaining potato slices. dot with 3 tablespoons butter then pour hot milk over potatoes. cover and bake at 355 for 50 minutes. uncover; sprinkle cheese over the top. return to the oven and bake, uncovered, for an additional 10 minutes, or until scalloped potatoes are tender and cheese has melted. scalloped potatoes serves 6 to 8.'}
# {'query': 'boneless beef sirloin, soy sauce, sesame oil, rice wine, egg white, garlic granules, ground black pepper, salt, peanuts, garlic, ginger, scallions, red bell pepper, soy sauce, rice wine, balsamic vinegar, sesame oil, sugar, chicken broth, cornstarch, roasted peanuts, cashew nuts, onion, brown bean sauce, bamboo shoots, rice', 'query_idx': 52593, 'top1_idx': np.int64(76806), 'top1_similarity': np.float32(0.8597299), 'top5_indices': [np.int64(76806), np.int64(70290), np.int64(49391), np.int64(52732), np.int64(71373)], 'top5_similarities': [np.float32(0.8597299), np.float32(0.8589438), np.float32(0.85885), np.float32(0.8581586), np.float32(0.8581456)], 'true_recipe': 'kung pao beef\n\ningredients:\n\n1 1/2 lbs boneless beef sirloin\n1 tablespoon soy sauce\n2 tablespoons sesame oil\n1 tablespoon rice wine or 1 tablespoon sherry wine\n1 egg white (lightly beaten)\n1/2 teaspoon garlic granules\n1/2 teaspoon ground black pepper\n1/2 teaspoon salt\n\n2 tablespoons peanuts or 2 tablespoons corn oil\n1 tablespoon minced garlic\n1/2 tablespoon grated ginger\n2 scallions (cut into 1/2&amp;#8221; pieces)\n1 red bell pepper (cut into pieces)\n2 tablespoons soy sauce\n3 tablespoons rice wine or 3 tablespoons sherry wine\n2 tablespoons balsamic vinegar\n2 tablespoons sesame oil\n1 teaspoon sugar\n1 cup chicken broth\n1 tablespoon cornstarch (dissolved in 2 tbl. water)\n1/4 cup roasted peanuts\n1/4 cup cashew nuts\n1 small onion (cubed &amp; segments separated)\n2 tablespoons brown bean sauce\n1 (8 ounce) can bamboo shoots\nrice\n\nsteps:\ntrim any fat from the steak &amp; cut the beef into 1 inch pieces.\ncombine the marinade ingredients in a bowl.\nadd the beef &amp; stir to coat.\ncover the bowl with plastic wrap &amp; marinate in the refrigerator for 1 hour.\nplace the peanut oil or corn oil in a wok, swirling to coat the sides, &amp; place over high heat.\nadd the garlic &amp; ginger &amp; continue to cook to infuse the oil.\nadd the scallions &amp; bell pepper.\nremove the beef from the marinade &amp; add it to the wok.\nstir-fry the beef for 3 minutes until brown.\nblend in soy sauce, rice wine or sherry, balsamic vinegar, sugar, sesame oil, brown bean sauce, bamboo shoots &amp; chicken broth.\ndissolve the cornstarch slurry &amp; add it to the wok, stirring to thicken.\nsprinkle in the peanuts &amp; cashews &amp; stir until everything is well coated. serve over steamed rice if desired.'}
# {'query': 'potatoes, butter, flour, milk, cream, blue cheese, breadcrumbs', 'query_idx': 41791, 'top1_idx': np.int64(23797), 'top1_similarity': np.float32(0.7416723), 'top5_indices': [np.int64(23797), np.int64(26791), np.int64(35079), np.int64(16661), np.int64(22894)], 'top5_similarities': [np.float32(0.7416723), np.float32(0.7295607), np.float32(0.7258806), np.float32(0.72252405), np.float32(0.7216568)], 'true_recipe': 'blue cheese potatoes delmonico\n\ningredients:\n8 medium potatoes\n1/2 cup butter\n1/2 cup flour\n1 cup milk\n1 cup cream\n1/2 cup blue cheese, crumbled\n1/3 cup breadcrumbs\n\nsteps:\npre-heat the oven to 375.\nboil the potatoes.\nallow to coolslightly and dice.\nplace in a casserole dish.\nmelt the butter in a saucepan.\nwhisk in the flour and cook for 5 minutes, stirring frequently.\nwhisk in the milk and cream.\nreduce the heat and simmer for 20 minutes.\nwhisk in the cheese until blended.\npour over the potatoes.\ntop with the breadcrumbs and bake for 25 minutes.'}
# {'query': 'fresh asparagus, onion, leek, milk, low sodium chicken broth, chicken breast, garlic cloves, butter, flour, vegetable oil, grains of paradise, mustard seeds, dried marjoram, salt, parmesan cheese', 'query_idx': 28275, 'top1_idx': np.int64(23797), 'top1_similarity': np.float32(0.7887093), 'top5_indices': [np.int64(23797), np.int64(37068), np.int64(79824), np.int64(52281), np.int64(11950)], 'top5_similarities': [np.float32(0.7887093), np.float32(0.78633916), np.float32(0.7860717), np.float32(0.7812783), np.float32(0.78108466)], 'true_recipe': 'green chicken soup for the soul\n\ningredients:\n2 lbs fresh asparagus\n1 medium onion\n1 large leek\n4 cups milk\n2 cups low sodium chicken broth\n1 lb chicken breast, cooked\n4 garlic cloves, minced\n3 tablespoons butter\n3 tablespoons flour\n2 tablespoons vegetable oil\n1 1/2 teaspoons grains of paradise\n1 1/2 teaspoons mustard seeds\n1 tablespoon dried marjoram\nsalt\nparmesan cheese, grated\n\nsteps:\nstart milk and chicken broth boiling along with a pinch of salt.\nwhile waiting to heat up, remove the woody ends of the asparagus and chop into 1" pieces, then add to liquid mixture.\nallow to simmer for 15 - 20 minutes.\nwhile that is simmering, coarsely chop onion and leek.\nheat oil in a large skillet over medium-low heat.\nadd leeks, onions, garlic, and a couple good pinches of salt (maybe 1/2 tsp.) and cover, stirring every couple of minutes.\ncontinue sweating onions and leeks until they are nice and tender.\nwhen asparagus is tender, add marjoram and use a stick blender or a food processor to puree the mixture.\nin a large sauce pan, melt butter over medium high heat, then add flour, stirring constantly until the mixture is blended and foamy, about 1 minute. this makes a roux.\nmix the asparagus puree mixture into the roux and allow to come to a simmer but do not let it boil.\ngrind the mustard and grains of paradise and stir into the soup.\nstir in onions and leeks.\nshred chicken breasts and add to the soup.\nallow to simmer a couple more minutes.\nserve topped with parmesan cheese.'}
# {'query': 'dried great northern beans, olive oil, garlic cloves, diced green chilies, ground cumin, dried oregano, ground cloves, cayenne pepper, boneless skinless chicken breasts, chicken broth, cheddar cheese, salt, pepper, sour cream, salsa, fresh cilantro, tortilla chips', 'query_idx': 4087, 'top1_idx': np.int64(52732), 'top1_similarity': np.float32(0.8467586), 'top5_indices': [np.int64(52732), np.int64(18037), np.int64(47225), np.int64(39449), np.int64(34673)], 'top5_similarities': [np.float32(0.8467586), np.float32(0.84345764), np.float32(0.8408319), np.float32(0.84009194), np.float32(0.83960414)], 'true_recipe': "slow cooker white chili\n\ningredients:\n1 lb dried great northern beans (or 3 cans, drained)\n1 tablespoon olive oil\n4 garlic cloves, minced\n1 (8 ounce) can diced green chilies (with liquid)\n2 teaspoons ground cumin\n2 teaspoons dried oregano\n1/4 teaspoon ground cloves\n1/4 teaspoon cayenne pepper\n2 lbs boneless skinless chicken breasts (i leave them whole and shred them- you can dice if you prefer them that way)\n6 cups chicken broth\n2 cups grated cheddar cheese, divided\n1 teaspoon salt\n1 teaspoon pepper\nsour cream\nsalsa\nfresh cilantro\ntortilla chips\n\nsteps:\nif using dry beans, cover with water and soak overnight. drain, discarding water. if using canned beans, drain well and rinse.\nsaute onions in olive oil until soft. add garlic, green chilies (incl liquid from can), cumin, oregano, cloves, and cayenne. saute for 5 minutes. (you may skip this step if you're short on time).\nplace all ingredients into slow cooker except cheese and garnishes.\ncover. cook on low 8-10 hrs or high 4-6 hours.\nif whole chicken breasts were used, shred them and add them back to the crock pot. add in 1 cup of cheese. stir until melted.\nserve with garnishes and remaining cheese."}
# {'query': 'chocolate chip cookies, cool whip, milk, amaretto', 'query_idx': 6916, 'top1_idx': np.int64(34686), 'top1_similarity': np.float32(0.7036251), 'top5_indices': [np.int64(34686), np.int64(42897), np.int64(23797), np.int64(5742), np.int64(22894)], 'top5_similarities': [np.float32(0.7036251), np.float32(0.7030647), np.float32(0.7001585), np.float32(0.69897187), np.float32(0.6989333)], 'true_recipe': 'chocolate chip cookie cool whip dessert\n\ningredients:\n2 (350 g) packages store bought chocolate chip cookies\n2 (8 ounce) containers cool whip or 2 (8 ounce) containers cool whip lite\n1/2 cup milk\n1/4 cup amaretto (or your favourite liquour)\n\nsteps:\ncombine milk and amaretto in a shallow bowl.\ndip cookies into the milk/amaretto mixture, and place a single layer of cookies in the bottom of a deep dessert dish.\nonce cookies cover the bottom of the dish, spoon out a layer of cool whip over the cookies so that it covers the cookies completely. layer should be about an inch thick.\nrepeate layers, placing cookies so that it covers up the cool whip, then cool whip to cover up the cookies.\nend the layering with a layer of cool whip.\ncrumble remaining cookies over the top of your dessert as garnish.\nrefrigerate for 1-2 hours.\nserve cold.'}
# {'query': 'all-purpose flour, brown sugar, rolled oats, walnuts, coconut, salt, cinnamon, egg, butter, jam', 'query_idx': 62122, 'top1_idx': np.int64(31695), 'top1_similarity': np.float32(0.8140169), 'top5_indices': [np.int64(31695), np.int64(59218), np.int64(39201), np.int64(9792), np.int64(17830)], 'top5_similarities': [np.float32(0.8140169), np.float32(0.8103137), np.float32(0.81002426), np.float32(0.8065077), np.float32(0.8046206)], 'true_recipe': "jam mazurkas (inspired by mean chef)\n\ningredients:\n4 cups all-purpose flour\n2 cups brown sugar\n2 cups rolled oats\n1 cup walnuts, ground\n1 1/2 cups coconut\n3/4 teaspoon salt\n1 -1 1/2 teaspoon cinnamon (i prefer the lesser amount)\n1 large egg\n12 ounces butter, melted and cooled\n1 3/4 lbs jam (use a good-quality one of your choosing)\n\nsteps:\npreaheat oven to 350°f.\ncombine all dry ingredients in a large bowl. break up any clumps of sugar with your finger tips and work the ingredients to mix them.\nadd melted butter and egg and work with fingers (i used one hand so i wouldn't get both gunky) to combine well.\npress half of dough in a foil-lined 15 x 10 inch pan, working well into edges and pressing down to compact.\nspread out jam of your choosing to within 1/2 inch of edges of pan - do not be tempted to use more jam than called for, the bars will be too sweet.\ntake handfuls of remaining dough mixture and crumble it over pan, distributing evenly. press down with palms of hand to compact - but not too hard.\nbake until golden-brown. 50 minutes in my oven (and to my taste).\ncool completely before cutting. cut lengthwise into 4 even rows and crosswise into 6."}
# {'query': 'potatoes, eggs, onion, celery, kraft salad dressing, mustard, milk, pickles, basil, parsley flakes, salt and pepper, stuffed green olive, paprika', 'query_idx': 41373, 'top1_idx': np.int64(24397), 'top1_similarity': np.float32(0.8475319), 'top5_indices': [np.int64(24397), np.int64(11950), np.int64(56775), np.int64(28427), np.int64(63766)], 'top5_similarities': [np.float32(0.8475319), np.float32(0.8465171), np.float32(0.8426349), np.float32(0.84232295), np.float32(0.84153473)], 'true_recipe': "janet's potato salad\n\ningredients:\n8 -10 potatoes\n4 hard-boiled eggs, , sliced\n1 medium onion, diced\ncelery, diced or celery flakes\nkraft salad dressing\nmustard\nmilk\ndiced pickles or diced pickle relish\n1/2 teaspoon basil\n1/2 teaspoon parsley flakes\nsalt and pepper\nstuffed green olive\npaprika\n\nsteps:\nwash potatoes, cut in half and boil with skins on.\nwhen cooled, remove skins and cube.\nadd onion, and diced celery.\nset aside.\nmix salad dressing, mustard, pickles/relish, spices, salt and pepper, and a tbsp or so of pickle juice.\nmix well, thin out with milk, using your own judgment as to consistancy.\npour over cubed potatoes and mix well.\ngently stir in sliced eggs, reserving 5-6 slices for garnish.\npour into serving bowl, place remaining eggs on top, put one olive slice on top of each egg slice, sprinkle with paprika and parsley flakes."}
# {'query': 'raspberry vodka, lemonade, tonic water', 'query_idx': 36981, 'top1_idx': np.int64(18392), 'top1_similarity': np.float32(0.71148205), 'top5_indices': [np.int64(18392), np.int64(13314), np.int64(35025), np.int64(15573), np.int64(21752)], 'top5_similarities': [np.float32(0.71148205), np.float32(0.69856685), np.float32(0.69328), np.float32(0.69180906), np.float32(0.6917782)], 'true_recipe': 'blue bombsickle\n\ningredients:\n1 ounce blue raspberry vodka\n3 ounces lemonade\ntonic water\n\nsteps:\nplace vodka, lemonade and a splash of tonic in a martini shaker over ice.'}
# {'query': 'boneless skinless chicken breast, onion, garlic, frozen broccoli cuts, boiling water, long-grain rice, sliced mushrooms, chicken bouillon granule, ground ginger, pepper, salted cashews', 'query_idx': 18709, 'top1_idx': np.int64(27659), 'top1_similarity': np.float32(0.8313801), 'top5_indices': [np.int64(27659), np.int64(39596), np.int64(39432), np.int64(5264), np.int64(8125)], 'top5_similarities': [np.float32(0.8313801), np.float32(0.8284882), np.float32(0.8265109), np.float32(0.82558745), np.float32(0.8250134)], 'true_recipe': 'cashew chicken casserole\n\ningredients:\n1 lb boneless skinless chicken breast, cut into 1 inch cubes\n1 medium onion, chopped\n2 cloves garlic, minced\n2 cups frozen broccoli cuts\n1 3/4 cups boiling water\n1 cup uncooked long-grain rice\n1 (6 ounce) jar sliced mushrooms, drained\n1 tablespoon chicken bouillon granule\n1 teaspoon ground ginger\npepper\n1 cup salted cashews, divided\n\nsteps:\nin a mixing bowl, add in all ingredients except the cashews; mix well to combine.\npour mixture into a greased shallow 1 1/2 quart casserole dish.\ncover and bake at 375 degrees for 45-55 minutes or until rice is tender and chicken is not pink.\nstir in 3/4 cup of cashews.\nsprinkle remaining cashews on top of casserole.\nserve warm.'}
# {'query': 'cream, queso fresco, sugar, walnuts, pomegranate, cilantro, white onion, cooking oil, ground beef, blanched slivered almonds, cinnamon, cumin, raisins, green olives, dried fruit, poblano chiles, eggs, flour, vegetable oil', 'query_idx': 52897, 'top1_idx': np.int64(14348), 'top1_similarity': np.float32(0.8586813), 'top5_indices': [np.int64(14348), np.int64(75705), np.int64(18037), np.int64(34673), np.int64(8764)], 'top5_similarities': [np.float32(0.8586813), np.float32(0.85392904), np.float32(0.8534837), np.float32(0.85242593), np.float32(0.85235023)], 'true_recipe': 'chiles en nogada\n\ningredients:\n\n1 cup cream\n1/2 cup queso fresco\n1 tablespoon sugar (or more to taste)\n1/3 cup chopped walnuts\n1 small pomegranate (or more about 1/2 cup, more if you wish, for garnish)\n1 sprig cilantro (for garnish)\n\n1/2 small white onion, finely chopped\ncooking oil (enough to coat bottom of pan)\n1 lb ground beef (or ground pork, or use cooked shredded pork)\n1/2 cup blanched slivered almonds or 1/2 cup other nuts\n1 teaspoon cinnamon\n1 teaspoon cumin\n1/4 cup raisins (soaked in hot water if hard, discard water)\n2 tablespoons sliced pitted green olives\n2 tablespoons diced dried fruit (such as apples, dried apricots, dried or candied pineapple, or mexican cactus candy dulce de biznaga)\n\n8 poblano chiles, toasted, peeled, slit down the side and seeded\n\n10 eggs, separated\n1/2 cup flour\nvegetable oil (for frying)\n\nsteps:\nfor the sauce: in a blender combine first 4 ingredients until smooth.\nthe sauce is to be served at room temperature, do not heat.\nfor the filling: in a large sauté pan cook onion and garlic in oil over medium heat until golden brown.\nadd remaining ingredients and cook until beef is done.\nstuff chiles with meat mixture.\n(note: you can use toothpicks to keep the chiles closed after they have been stuffed or just handle them very carefully).\nfor the batter: beat egg whites until stiff peaks form.\nin a separate bowl beat yolks well.\nfold yolks into beaten whites.\nsprinkle about 2 1/2 tablespoons of the flour on top and fold it into the egg mixture.\nsprinkle a plate with a layer of flour and lay each stuffed chile in it.\nsprinkle more flour on top of the chiles so that they are thoroughly coated; this helps the batter adhere.\nin a large sauté pan heat about 1/4 inch oil over medium-high heat.\nwhen oil is hot, pick up each floured chile by the stem and dip it the batter.\nthen gently lay it in the oil.\nas the chiles fry, lift the pan by the handle and tilt it back and forth so that the edges of the battered chiles are cooked (this makes them easier to turn too).\nwhen the first side is golden brown, turn and cook the other side.\nremove with a slotted spoon and drain on several layers of paper towels.\nkeep warm in a low oven (about 150 or 200 degrees) until all are done.\nnote: the chiles may be prepared in advance and reheated on a nonstick baking sheet for about 8 minutes at 450 degrees.\nor they may be served at room temperature.\nto serve: to serve, place a stuffed chile on each plate and cover with walnut cream sauce (the nogada).\nsprinkle with pomegranate seeds and garnish plate with cilantro.'}
# {'query': 'fresh strawberries, sugar, bananas', 'query_idx': 28127, 'top1_idx': np.int64(5264), 'top1_similarity': np.float32(0.6558157), 'top5_indices': [np.int64(5264), np.int64(22564), np.int64(4098), np.int64(21284), np.int64(22894)], 'top5_similarities': [np.float32(0.6558157), np.float32(0.6514164), np.float32(0.6499259), np.float32(0.6482202), np.float32(0.647806)], 'true_recipe': "easy strawberry banana salad\n\ningredients:\n1 lb fresh strawberries, quartered\n1/4 cup sugar (or to taste)\n3 bananas, sliced\n\nsteps:\nadd strawberries to a bowl and add sugar. stir slightly.\nlet sit to macerate for 10 minutes or until juices form. (you don't really even have to let it sit very long. just until the sugar is dissolved.).\nadd bananas and stir gently to coat.\nallow to sit for up to 30 minutes (but you can eat right away)."}
# {'query': 'bananas, ice, honey, pineapple chunk, water', 'query_idx': 9918, 'top1_idx': np.int64(38714), 'top1_similarity': np.float32(0.7002783), 'top5_indices': [np.int64(38714), np.int64(20014), np.int64(35027), np.int64(9068), np.int64(8391)], 'top5_similarities': [np.float32(0.7002783), np.float32(0.6925193), np.float32(0.6922586), np.float32(0.691592), np.float32(0.6901248)], 'true_recipe': 'banana-pineapple slushie\n\ningredients:\n2 frozen bananas, peeled and sliced\n1 1/2 cups crushed ice\n1/4 cup honey\n1 cup pineapple chunk\n1/2 cup water\n\nsteps:\ncombine pineapple, honey and ice in blender.\nblend till smooth.\nadd banana.\nblend until desired smoothness is reached.\nyou may have to stop blender to stir slushie.\nadd water if needed.'}
# {'query': 'cream cheese, dark chocolate, ground hazelnuts, creme de cacao, cocoa, white chocolate, dark chocolate, chocolate sprinkles, coconut', 'query_idx': 10118, 'top1_idx': np.int64(38503), 'top1_similarity': np.float32(0.81546044), 'top5_indices': [np.int64(38503), np.int64(9792), np.int64(6476), np.int64(11509), np.int64(1445)], 'top5_similarities': [np.float32(0.81546044), np.float32(0.8151011), np.float32(0.81253797), np.float32(0.810964), np.float32(0.80814993)], 'true_recipe': 'chocolate truffles\n\ningredients:\n250 g cream cheese, softened\n200 g toblerone dark chocolate, melted\n1/2 cup ground hazelnuts\n2 teaspoons creme de cacao or 2 teaspoons baileys irish cream\n\ndrinking cocoa\nmelted white chocolate, grated\nmelted dark chocolate, grated\nchocolate sprinkles\ncoconut\n\nsteps:\nmix all ingredients together.\nrolll into small balls, (wet hands are handy) approximately 2.5cm diametres each.\ncoat in either cocoa, melted or grated chocolate, sprinkles or coconut (or maybe you may have a different preference for rolling truffles in.).\nchill for 2 hours.\nserve.'}
# ...
# {'query': 'tomatoes, garlic clove, olive oil, salt, pepper, baguette, serrano ham, fresh basil', 'query_idx': 543, 'top1_idx': np.int64(39596), 'top1_similarity': np.float32(0.79296464), 'top5_indices': [np.int64(39596), np.int64(30204), np.int64(15573), np.int64(13513), np.int64(16197)], 'top5_similarities': [np.float32(0.79296464), np.float32(0.7818675), np.float32(0.78109324), np.float32(0.78038764), np.float32(0.7759179)], 'true_recipe': 'spanish tomato bread with jam&oacute;n serrano\n\ningredients:\n4 ripe tomatoes, chopped\n1 -2 garlic clove, finely chopped\n3 tablespoons olive oil\nsalt\npepper\n20 -24 slices baguette\n5 -6 slices serrano ham\nchopped fresh basil or flat leaf parsley, to serve\n\nsteps:\nmix together the chopped tomatoes, garlic clove/s, olive oil, salt and pepper.\nkeep the mixture in the fridge until needed.\nto serve, toast the slices of baguette. spoon a little tomato topping on to each piece of toast.\ntear the slices of jamón serrano into pieces and put one piece on each slice of bread.\narrange on a large attractive plate, sprinkle with chopped basil or flat leaf parsley and eat!'}
# {'query': 'red snapper fillets, lime juice, salt, cooking spray, vegetable oil, onion, fresh tomatoes, roasted red peppers, jalapeno pepper, lime slice', 'query_idx': 79845, 'top1_idx': np.int64(17837), 'top1_similarity': np.float32(0.824008), 'top5_indices': [np.int64(17837), np.int64(39596), np.int64(2226), np.int64(18398), np.int64(61635)], 'top5_similarities': [np.float32(0.824008), np.float32(0.8238877), np.float32(0.8235967), np.float32(0.82335424), np.float32(0.8229541)], 'true_recipe': 'red snapper veracruz skillet\n\ningredients:\n6 (4 ounce) red snapper fillets, 1/2 inch thick\n1/2 cup lime juice\n1/2 teaspoon salt\ncooking spray\n1 teaspoon vegetable oil\n1 cup thinly sliced onion\n2 cups chopped fresh tomatoes\n4 ounces diced roasted red peppers, drained\n1 teaspoon jalapeno pepper (without seeds)\nlime slice\n\nsteps:\nmarinate fillets in refrigerator in the lime juice and salt for 2 hours.\ncoat a large nonstick skillet with cooking spray and add oil. heat to medium-high.\nsaute onion until tender. add tomato, red pepper, and jalapeno pepper.\ncover and cook 7 minutes; stir occasionally.\nremove fillets from marinade and arrange over mixture in skillet. discard marinade.\ncover and cook 6 minutes on each side or until fish flakes easily.\nremove fillets and keep warm. continue cooking tomato mixture uncovered until any excess liquid evaporates.\nserve with lime slices if desired.'}
# {'query': 'sliced almonds, sweetened coconut, butter, sugar, water, light corn syrup, salt', 'query_idx': 10238, 'top1_idx': np.int64(9792), 'top1_similarity': np.float32(0.7788288), 'top5_indices': [np.int64(9792), np.int64(38503), np.int64(16661), np.int64(59218), np.int64(14406)], 'top5_similarities': [np.float32(0.7788288), np.float32(0.7690815), np.float32(0.7666448), np.float32(0.7621317), np.float32(0.7618013)], 'true_recipe': 'butter almond crunch\n\ningredients:\n3/4 cup sliced almonds\n3/4 cup shredded sweetened coconut\n1/2 cup butter or 1/2 cup margarine\n1 1/2 cups sugar\n3 tablespoons water\n1 tablespoon light corn syrup\n1/2 teaspoon salt\n\nsteps:\ncombine almonds and coconut.\nspread in a thin layer over bottom of a buttered 13 x 9-inch pan.\nmelt butter or margine in a saucepan.\nstir in the rest of the ingredients.\ncook, without stirring until mixture comes to soft crack stage, 290 degrees f.\nremove from heat and pour in a thin stream evenly over almonds and coconut.\ncool.\nbreak into pieces.\nstore in an air-tight container.'}
# {'query': 'buttermilk, all purpose greek seasoning, boneless skinless chicken breasts, dry breadcrumbs, kosher salt, parmesan cheese', 'query_idx': 59067, 'top1_idx': np.int64(27659), 'top1_similarity': np.float32(0.8058943), 'top5_indices': [np.int64(27659), np.int64(14800), np.int64(37068), np.int64(5264), np.int64(27091)], 'top5_similarities': [np.float32(0.8058943), np.float32(0.7991911), np.float32(0.79305816), np.float32(0.7923444), np.float32(0.7908933)], 'true_recipe': "oven fried chicken your way\n\ningredients:\n1/2 cup buttermilk\n1 tablespoon all purpose greek seasoning (see instructions, any spice blend can be used)\n1 1/2 lbs boneless skinless chicken breasts\n1/2 cup dry breadcrumbs (unseasoned)\n1 teaspoon kosher salt\n1/4 cup parmesan cheese (freshly grated is best)\n\nsteps:\nthis recipe is called your way because you can use any spice blend you want for seasoning; mccormicks greek seasoning is excellent, as is emeril's essence; make your own up if you want.\nin a flat dish like a pie plate, combine buttermilk and spice blend.\nor, if making this up early in the day, combine in a large ziploc bag instead, so chicken can marinate for a few hours in the fridge.\ncombine breadcrumbs, salt and parmesan in another flat dish; set aside if you want chicken to marinate in fridge for a few hours.\ncut chicken breasts into large chunks.\nif you are making this up early in the day, place chicken pieces into the ziploc bag along with the buttermilk mixture and close bag tightly; make sure all pieces of chicken are coated with buttermilk mixture; let sit in fridge until ready to coat.\nif you don't have time for this, just dip chicken chunks into buttermilk mixture, making sure pieces are thoroughly coated.\npreheat oven to 400f; have ready a baking sheet sprayed with nonstick cooking spray or lined with parchment paper.\nafter chicken is coated with buttermilk mixture, dredge in breadcrumb mixture thoroughly, then place on prepared baking sheet.\nbake for approximately 20 to 25 minutes, or until chicken is just cooked through."}
# {'query': 'semi-sweet chocolate chips, ground cinnamon, unsalted cashews, oyster crackers', 'query_idx': 26210, 'top1_idx': np.int64(26065), 'top1_similarity': np.float32(0.76672703), 'top5_indices': [np.int64(26065), np.int64(14800), np.int64(42897), np.int64(17976), np.int64(27659)], 'top5_similarities': [np.float32(0.76672703), np.float32(0.7611587), np.float32(0.75020105), np.float32(0.75003237), np.float32(0.74856937)], 'true_recipe': 'nut-cracker candy\n\ningredients:\n12 ounces semi-sweet chocolate chips\n3 tablespoons ground cinnamon\n1 cup unsalted cashews\n1 cup oyster crackers\n\nsteps:\nmelt chocolate in a medium saucepan over low heat.\nstir in cinnamon.\nfold in cashews and crackers.\ndrop by heaping teaspoonfuls onto waxed paper.\ncool completely and store in an airtight container.'}
# {'query': 'apples, light brown sugar, butter, lemon juice, vanilla ice cream, nuts', 'query_idx': 17781, 'top1_idx': np.int64(1445), 'top1_similarity': np.float32(0.78968966), 'top5_indices': [np.int64(1445), np.int64(21284), np.int64(36712), np.int64(31695), np.int64(28113)], 'top5_similarities': [np.float32(0.78968966), np.float32(0.7874782), np.float32(0.7809148), np.float32(0.7800723), np.float32(0.77978635)], 'true_recipe': 'hot apple sundae\n\ningredients:\n2 apples, cut in 1/4 inch slices\n2 tablespoons light brown sugar\n2 tablespoons butter\n1 teaspoon lemon juice\nvanilla ice cream\n1/3 cup nuts (your choice)\n\nsteps:\ncook apples in butter, sugar and lemon juice until tender.\nspoon apples and syrup in dessert dishes.\ntop with ice cream and nuts.'}
# {'query': 'beans, lard, longhorn cheese', 'query_idx': 40651, 'top1_idx': np.int64(32766), 'top1_similarity': np.float32(0.642748), 'top5_indices': [np.int64(32766), np.int64(14606), np.int64(31639), np.int64(29972), np.int64(18962)], 'top5_similarities': [np.float32(0.642748), np.float32(0.6357939), np.float32(0.6326705), np.float32(0.6321832), np.float32(0.63166916)], 'true_recipe': 'frijoles refritos (refried beans)\n\ningredients:\n2 cups beans, cooked\n3 tablespoons lard or 3 tablespoons bacon drippings\n1/2 cup longhorn cheese, grated\n\nsteps:\nheat lard or bacon drippings in frying pan or saucepan.\nadd beans, mash and simmer for 5 minutes.\ntop with cheese and serve when melted.\nnote: this along with green chili and/or salsa is a great burrito filling.'}
# {'query': 'extra virgin olive oil, chicken breast tenders, chicken broth, onion, garlic cloves, dried cilantro, fresh ginger, lemon zest, ground cumin, turmeric, coconut milk, macadamia nuts, sugar, ground red pepper, shrimp, tamarind paste, water, green onion', 'query_idx': 17348, 'top1_idx': np.int64(52732), 'top1_similarity': np.float32(0.8143859), 'top5_indices': [np.int64(52732), np.int64(73656), np.int64(77959), np.int64(53159), np.int64(72976)], 'top5_similarities': [np.float32(0.8143859), np.float32(0.81435263), np.float32(0.8139522), np.float32(0.81383544), np.float32(0.81376714)], 'true_recipe': "coconut chicken (clone of cheesecake factory's bang bang chicken\n\ningredients:\n2 tablespoons extra virgin olive oil\n1 lb chicken breast tenders\n1 tablespoon chicken broth\n1 medium onion, chopped\n2 garlic cloves, minced\n3/4 teaspoon dried cilantro\n1 teaspoon fresh ginger, grated\n1 teaspoon lemon zest, finely chopped\n1/8 teaspoon ground cumin\n1 pinch turmeric\n1 cup coconut milk (substitute light, no sugar added, if desired)\n2 tablespoons macadamia nuts, finely ground\n1 teaspoon sugar (substitute splenda, if desired)\n1/4 teaspoon ground red pepper\n2 cups shrimp, fully cooked\n1 tablespoon tamarind paste (available in indian and specialty stores)\n2 teaspoons water\nchopped green onion (to garnish)\n\nsteps:\nheat oil in a large skillet over medium-high heat. add chicken and cook 5 minutes per side or until browned and no longer pink in the center. remove chicken to a plate and set aside.\nheat the broth in the same skillet. add onion, garlic, cilantro, ginger, lemon zest, cumin and turmeric and cook for 5 minutes or until the onion is tender but not browned. stir in coconut milk, nuts, sugar, red pepper and shrimp. return the chicken to the skillet, cover and simmer for 10 minutes or until the chicken is heated through.\nremove the chicken and shrimp to a plate and keep warm. do not discard the sauce in the pan.\nin a small bowl, combine the tamarind paste and water. stir into the sauce in the skillet and gently boil until thickened and the mixture measures about 1 cup. evenly divide the chicken and shrimp among 4 plates.\ntop with sauce and garnish with green onion."}
# {'query': 'lean ground beef, onions, catsup, worcestershire sauce, salt and pepper, mild chili powder, head of cabbage, cucumber, onion, salt and pepper, vinegar, wesson oil, sugar', 'query_idx': 64237, 'top1_idx': np.int64(18392), 'top1_similarity': np.float32(0.8218658), 'top5_indices': [np.int64(18392), np.int64(37931), np.int64(28595), np.int64(75496), np.int64(31101)], 'top5_similarities': [np.float32(0.8218658), np.float32(0.8061142), np.float32(0.8052235), np.float32(0.8044416), np.float32(0.80356014)], 'true_recipe': 'mexican hamburgers\n\ningredients:\n\n3 lbs lean ground beef\n6 medium onions, chopped\n1 (15 ounce) bottle catsup\n4 tablespoons worcestershire sauce\nsalt and pepper\n2 tablespoons mild chili powder\n\n1 medium head of cabbage\n1 medium cucumber\n1 medium onion\nsalt and pepper\n1/2 cup vinegar\n1/2 cup wesson oil\n1/2 cup sugar\n\nsteps:\nmeat:\ncook hamburger meat and chopped onions in a large skillet until the fat is rendered from the meat and the onions are clear. drain all fat by placing meat in a colender and pressing with a spoon. return meat and onions to skillet and add catsup, worchestershire sauce, chili powder, salt and pepper. simmer very slowly for at least one hour, one and a half is better. a small amount of water can be added to keep from sticking. you can also add more catsup if it is becoming too dry, but the final product should be fairly firm without too much moisture. skim any fat that still remains on top. if you cook it properly to begin with, there will be very little.\nsomething magic happens when catsup (the good stuff) is cooked with chili powder. i use this in meatloaf and bar-b-q sauce also with wonderful results.\nslaw:\nuse a food processor to grate one medium head of cabbage. grate the cucumber fine, without peeling. grate the onion very fine. add the salt, pepper, vinegar, wesson oil and sugar. mix together. the slaw should be made at least a day in advance and placed in a covered dish in the refrigerator. it keeps for a week and seems to get better every day. this is a great slaw to serve with any meal and has the most unusual and delicious flavor of any slaw i ever tasted.\nit is very important to serve these on a toasted bun. place meat on the bun bottom and drain the slaw well. place a spoon full of well drained slaw on top of the meat and cover with the bun top. some people like the slaw on the side.\nthe meat freezes well, will keep in the cooler for a week and heats up in a microwave oven without any after-taste.\ncaution: these are highly adictive! they will become a family favorite after one try. little old ladies have been known to eat three on small buns.'}
# {'query': 'cream cheese, spring roll wrappers, prawns, seafood sauce, lemon juice', 'query_idx': 15818, 'top1_idx': np.int64(39596), 'top1_similarity': np.float32(0.7710574), 'top5_indices': [np.int64(39596), np.int64(23797), np.int64(5264), np.int64(18092), np.int64(37759)], 'top5_similarities': [np.float32(0.7710574), np.float32(0.76440775), np.float32(0.76418924), np.float32(0.7596812), np.float32(0.7592113)], 'true_recipe': 'prawn/shrimp appetizers\n\ningredients:\n150 g cream cheese, philly lite\n24 spring roll wrappers, cups see recipe <a href="https://www.geniuskitchen.com/recipe/spring-roll-wrapper-cups-512366">spring roll wrapper cups</a>\n1 cup prawns, cooked\n1 -1 1/2 tablespoon seafood sauce\nsqueeze lemon juice\n\nsteps:\ncook prawns, and chop off a larger piece of each prawn and save to put on the top, chop the rest of the prawns finely.\nadd the lemon juice and the seafood sauce (i use marie rose sauce) - many sauces are different thicknesses so start with the one tablespoon and just add more if necessary to the cheese and blend well.\nstir in the chopped prawns - or you could use smoked salmon.\nfill each cup with the cheese mixture and serve. great for parties or when entertaining. the filling can be made ahead - the same with the cups but the filling has to be put in the cups la late as possible.'}
#
# 📈 Precision@5 Results (Threshold: 0.7):
#    Mean:  95.52%

# %% [markdown]
# # 7. Ablation Studies (Retriever)

# %%
# Cosine vs Euclidean vs Manhattan
np.random.seed(42)

RETRIEVAL_SAMPLE_SIZE = 500
K_VALUES = [1, 3, 5, 7, 10]
RELEVANCE_THRESHOLD = 0.7

# Sample test queries and convert indices
retrieval_sample_indices = np.random.choice(
    len(test_dataset),
    size=min(RETRIEVAL_SAMPLE_SIZE, len(test_dataset)),
    replace=False
)
retrieval_sample_indices = [int(idx) for idx in retrieval_sample_indices]

# Define similarity metrics
similarity_methods = {
    "cosine": lambda q, E: cosine_similarity(q, E)[0],
    "euclidean": lambda q, E: 1 - (pairwise_distances(q, E, metric='euclidean')[0] / pairwise_distances(q, E, metric='euclidean')[0].max()),
    "manhattan": lambda q, E: 1 - (pairwise_distances(q, E, metric='manhattan')[0] / pairwise_distances(q, E, metric='manhattan')[0].max())
}

precision_at_k_metrics = {name: {k: [] for k in K_VALUES} for name in similarity_methods}

for i in tqdm(retrieval_sample_indices, desc="Retrieving recipes", ncols=100):
    i = int(i)
    query = test_dataset[i]['input_text']

    # Extract ingredients only
    if "using:" in query.lower():
        query_ingredients = query.split("using:")[-1].strip()
    else:
        query_ingredients = query.strip()

    # Compute query embedding
    query_emb = np.array(get_t5_embeddings([query_ingredients], model, tokenizer))

    # Compute Precision@K for each similarity method
    for name, func in similarity_methods.items():
        sims = func(query_emb, recipe_embeddings)
        # Top 20 excluding self
        all_indices = np.argsort(sims)[::-1]
        top_indices = [idx for idx in all_indices if idx != i][:20]
        top_sims = [sims[idx] for idx in top_indices]

        for k in K_VALUES:
            top_k_sims = top_sims[:k]
            relevant_count = sum(1 for sim in top_k_sims if sim >= RELEVANCE_THRESHOLD)
            precision = relevant_count / k
            precision_at_k_metrics[name][k].append(precision)

mean_precision_at_k = {
    name: [np.mean(precision_at_k_metrics[name][k]) for k in K_VALUES]
    for name in similarity_methods
}
# Out:
# Performing retrievals with different similarity metrics...
# Retrieving recipes:   0%|                                                   | 0/500 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:00<00:00, 41.14it/s]
# Retrieving recipes:   0%|                                           | 1/500 [00:01<15:24,  1.85s/it]
# 100%|██████████| 1/1 [00:00<00:00, 42.68it/s]
# Retrieving recipes:   0%|▏                                          | 2/500 [00:03<11:57,  1.44s/it]
# 100%|██████████| 1/1 [00:00<00:00, 64.56it/s]
# Retrieving recipes:   1%|▎                                          | 3/500 [00:03<09:28,  1.14s/it]
# 100%|██████████| 1/1 [00:00<00:00, 64.00it/s]
# Retrieving recipes:   1%|▎                                          | 4/500 [00:04<08:16,  1.00s/it]
# 100%|██████████| 1/1 [00:00<00:00, 49.74it/s]
# Retrieving recipes:   1%|▍                                          | 5/500 [00:05<07:35,  1.09it/s]
# 100%|██████████| 1/1 [00:00<00:00, 64.41it/s]
# Retrieving recipes:   1%|▌                                          | 6/500 [00:06<07:10,  1.15it/s]
# 100%|██████████| 1/1 [00:00<00:00, 47.65it/s]
# Retrieving recipes:   1%|▌                                          | 7/500 [00:07<07:12,  1.14it/s]
# 100%|██████████| 1/1 [00:00<00:00, 46.04it/s]
# Retrieving recipes:   2%|▋                                          | 8/500 [00:08<08:00,  1.02it/s]
# 100%|██████████| 1/1 [00:00<00:00, 54.61it/s]
# Retrieving recipes:   2%|▊                                          | 9/500 [00:09<08:44,  1.07s/it]
# 100%|██████████| 1/1 [00:00<00:00, 39.06it/s]
# Retrieving recipes:   2%|▊                                         | 10/500 [00:10<08:47,  1.08s/it]
# 100%|██████████| 1/1 [00:00<00:00, 36.67it/s]
# Retrieving recipes:   2%|▉                                         | 11/500 [00:11<08:47,  1.08s/it]
# 100%|██████████| 1/1 [00:00<00:00, 57.69it/s]
# Retrieving recipes:   2%|█                                         | 12/500 [00:12<07:59,  1.02it/s]
# 100%|██████████| 1/1 [00:00<00:00, 58.78it/s]
# Retrieving recipes:   3%|█                                         | 13/500 [00:13<07:23,  1.10it/s]
# 100%|██████████| 1/1 [00:00<00:00, 65.03it/s]
# Retrieving recipes:   3%|█▏                                        | 14/500 [00:13<06:58,  1.16it/s]
# 100%|██████████| 1/1 [00:00<00:00, 58.76it/s]
# Retrieving recipes:   3%|█▎                                        | 15/500 [00:14<06:39,  1.21it/s]
# 100%|██████████| 1/1 [00:00<00:00, 65.10it/s]
# Retrieving recipes:   3%|█▎                                        | 16/500 [00:15<06:27,  1.25it/s]
# 100%|██████████| 1/1 [00:00<00:00, 62.58it/s]
# Retrieving recipes:   3%|█▍                                        | 17/500 [00:16<06:17,  1.28it/s]
# 100%|██████████| 1/1 [00:00<00:00, 64.53it/s]
# Retrieving recipes:   4%|█▌                                        | 18/500 [00:16<06:09,  1.30it/s]
# 100%|██████████| 1/1 [00:00<00:00, 66.41it/s]
# Retrieving recipes:   4%|█▌                                        | 19/500 [00:17<06:07,  1.31it/s]
# 100%|██████████| 1/1 [00:00<00:00, 62.52it/s]
# Retrieving recipes:   4%|█▋                                        | 20/500 [00:18<06:04,  1.32it/s]
# 100%|██████████| 1/1 [00:00<00:00, 62.66it/s]
# Retrieving recipes:   4%|█▊                                        | 21/500 [00:19<05:59,  1.33it/s]
# 100%|██████████| 1/1 [00:00<00:00, 66.80it/s]
# Retrieving recipes:   4%|█▊                                        | 22/500 [00:19<05:56,  1.34it/s]
# 100%|██████████| 1/1 [00:00<00:00, 61.74it/s]
# Retrieving recipes:   5%|█▉                                        | 23/500 [00:20<05:57,  1.33it/s]
# 100%|██████████| 1/1 [00:00<00:00, 61.73it/s]
# Retrieving recipes:   5%|██                                        | 24/500 [00:21<05:56,  1.33it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.21it/s]
# Retrieving recipes:   5%|██                                        | 25/500 [00:22<06:56,  1.14it/s]
# 100%|██████████| 1/1 [00:00<00:00, 44.40it/s]
# Retrieving recipes:   5%|██▏                                       | 26/500 [00:23<07:21,  1.07it/s]
# 100%|██████████| 1/1 [00:00<00:00, 47.20it/s]
# Retrieving recipes:   5%|██▎                                       | 27/500 [00:24<07:31,  1.05it/s]
# 100%|██████████| 1/1 [00:00<00:00, 34.37it/s]
# Retrieving recipes:   6%|██▎                                       | 28/500 [00:25<07:51,  1.00it/s]
# 100%|██████████| 1/1 [00:00<00:00, 44.09it/s]
# Retrieving recipes:   6%|██▍                                       | 29/500 [00:26<07:14,  1.08it/s]
# 100%|██████████| 1/1 [00:00<00:00, 65.92it/s]
# Retrieving recipes:   6%|██▌                                       | 30/500 [00:27<06:50,  1.15it/s]
# 100%|██████████| 1/1 [00:00<00:00, 62.58it/s]
# Retrieving recipes:   6%|██▌                                       | 31/500 [00:27<06:31,  1.20it/s]
# 100%|██████████| 1/1 [00:00<00:00, 62.71it/s]
# Retrieving recipes:   6%|██▋                                       | 32/500 [00:28<06:15,  1.25it/s]
# 100%|██████████| 1/1 [00:00<00:00, 63.58it/s]
# Retrieving recipes:   7%|██▊                                       | 33/500 [00:29<06:05,  1.28it/s]
# 100%|██████████| 1/1 [00:00<00:00, 63.50it/s]
# Retrieving recipes:   7%|██▊                                       | 34/500 [00:30<05:58,  1.30it/s]
# 100%|██████████| 1/1 [00:00<00:00, 62.83it/s]
# Retrieving recipes:   7%|██▉                                       | 35/500 [00:30<05:52,  1.32it/s]
# 100%|██████████| 1/1 [00:00<00:00, 57.18it/s]
# Retrieving recipes:   7%|███                                       | 36/500 [00:31<05:48,  1.33it/s]
# 100%|██████████| 1/1 [00:00<00:00, 61.02it/s]
# Retrieving recipes:   7%|███                                       | 37/500 [00:32<05:45,  1.34it/s]
# 100%|██████████| 1/1 [00:00<00:00, 67.35it/s]
# Retrieving recipes:   8%|███▏                                      | 38/500 [00:33<05:41,  1.35it/s]
# 100%|██████████| 1/1 [00:00<00:00, 61
24it/s]
# 100%|██████████| 1/1 [00:00<00:00, 36.20it/s]
# Retrieving recipes:  97%|███████████████████████████████████████▊ | 485/500 [06:36<00:13,  1.07it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.34it/s]
# Retrieving recipes:  97%|███████████████████████████████████████▊ | 486/500 [06:37<00:13,  1.05it/s]
# 100%|██████████| 1/1 [00:00<00:00, 34.78it/s]
# Retrieving recipes:  97%|███████████████████████████████████████▉ | 487/500 [06:38<00:12,  1.01it/s]
# 100%|██████████| 1/1 [00:00<00:00, 28.14it/s]
# Retrieving recipes:  98%|████████████████████████████████████████ | 488/500 [06:39<00:11,  1.08it/s]
# 100%|██████████| 1/1 [00:00<00:00, 54.66it/s]
# Retrieving recipes:  98%|████████████████████████████████████████ | 489/500 [06:40<00:09,  1.16it/s]
# 100%|██████████| 1/1 [00:00<00:00, 43.48it/s]
# Retrieving recipes:  98%|████████████████████████████████████████▏| 490/500 [06:40<00:08,  1.22it/s]
# 100%|██████████| 1/1 [00:00<00:00, 47.03it/s]
# Retrieving recipes:  98%|████████████████████████████████████████▎| 491/500 [06:41<00:07,  1.24it/s]
# 100%|██████████| 1/1 [00:00<00:00, 49.14it/s]
# Retrieving recipes:  98%|████████████████████████████████████████▎| 492/500 [06:42<00:06,  1.29it/s]
# 100%|██████████| 1/1 [00:00<00:00, 44.60it/s]
# Retrieving recipes:  99%|████████████████████████████████████████▍| 493/500 [06:42<00:05,  1.32it/s]
# 100%|██████████| 1/1 [00:00<00:00, 48.01it/s]
# Retrieving recipes:  99%|████████████████████████████████████████▌| 494/500 [06:43<00:04,  1.33it/s]
# 100%|██████████| 1/1 [00:00<00:00, 51.16it/s]
# Retrieving recipes:  99%|████████████████████████████████████████▌| 495/500 [06:44<00:03,  1.35it/s]
# 100%|██████████| 1/1 [00:00<00:00, 52.53it/s]
# Retrieving recipes:  99%|████████████████████████████████████████▋| 496/500 [06:45<00:02,  1.36it/s]
# 100%|██████████| 1/1 [00:00<00:00, 47.69it/s]
# Retrieving recipes:  99%|████████████████████████████████████████▊| 497/500 [06:45<00:02,  1.36it/s]
# 100%|██████████| 1/1 [00:00<00:00, 45.94it/s]
# Retrieving recipes: 100%|████████████████████████████████████████▊| 498/500 [06:46<00:01,  1.36it/s]
# 100%|██████████| 1/1 [00:00<00:00, 49.40it/s]
# Retrieving recipes: 100%|████████████████████████████████████████▉| 499/500 [06:47<00:00,  1.38it/s]
# 100%|██████████| 1/1 [00:00<00:00, 39.84it/s]
# Retrieving recipes: 100%|█████████████████████████████████████████| 500/500 [06:48<00:00,  1.23it/s]

# %%
precision_table = []

for name in similarity_methods:
    for k in K_VALUES:
        mean_val = np.mean(precision_at_k_metrics[name][k])
        precision_table.append({
            "Metric": name,
            "K": k,
            "Mean Precision@K": round(mean_val, 3)
        })

precision_df = pd.DataFrame(precision_table)

print(precision_df.pivot(index="K", columns="Metric", values="Mean Precision@K").round(3))
# Out:
# 📊 Retriever Ablation Results (Mean Precision@K):
# Metric  cosine  euclidean  manhattan
# K
# 1        0.966      0.774      0.718
# 3        0.965      0.759      0.701
# 5        0.963      0.750      0.688
# 7        0.961      0.740      0.680
# 10       0.960      0.729      0.671

# %%
# Visualisation of Precision@K Degradation
plt.figure(figsize=(9, 5))

colors = {"cosine": "steelblue", "euclidean": "orange", "manhattan": "green"}

for name in similarity_methods:
    plt.plot(K_VALUES, mean_precision_at_k[name],
             marker='o', linewidth=2, markersize=6, color=colors[name], label=f'{name} (mean)')

plt.axhline(RELEVANCE_THRESHOLD, color='red', linestyle='--', label=f'Threshold ({RELEVANCE_THRESHOLD})')

plt.xlabel('K')
plt.ylabel('Precision@K')
plt.title('Similarity Metric Comparison')
plt.xticks(K_VALUES)
plt.ylim(0, 1.05)
plt.grid(alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()
